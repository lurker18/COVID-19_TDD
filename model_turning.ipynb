# %%
from matplotlib import pyplot as plt
from datetime import datetime, timedelta
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
from tqdm import tqdm

import tensorflow as tf
import pandas as pd        #pandas 1.3.2 버전 권장! 현제 1.4.1 버전에서 오류있음
import numpy as np
import pickle
import json
import os

# %% [markdown]
# ## 데이터 불러오기

# %%
data_path = './data/'
model_path = './saved/'
image_path = './images/'

index = pd.read_csv(data_path + 'us_index.csv')
epidemic = pd.read_csv(data_path + 'us_epidemiology.csv')
trends = pd.read_csv(data_path + 'us_google-search_trends.csv')
states = json.load(open(data_path + 'us_adjacent_states.json', 'r'))

# %% [markdown]
# ## 누락 데이터 처리

# %%
epidemic = epidemic.fillna(method='ffill')
epidemic = epidemic.fillna(0)
trends = trends.fillna(method='ffill')
trends = trends.fillna(0)

# %% [markdown]
# ## 편의를 위한 함수들

# %%
# name > code
def get_region_code(region_name, index=index):
    ''' 지역 이름을 코드로 변환하는 함수
    Args:
      region_name (str): 지역의 이름 ex) New York

    Returns:
      region_code (str): 지역의 코드 ex) US_NY
    '''
    if region_name == 'US':
        return region_name

    region_code = index[(index['subregion1_name'] == region_name) &
                      (index['aggregation_level'] == 1)]['key'].values[0]
    return region_code


# code > name
def get_region_name(region_code, index=index):
    ''' 지역 코드를 이름으로 변환하는 함수
    Args:
      region_code (str): 지역의 코드

    Returns:
      region_name (str): 지역의 이름
    '''
    if region_code == 'US':
        return region_code

    country_code, subregion_code = region_code.split('_')
    region_name = index[(index['country_code'] == country_code) &
                      (index['subregion1_code'] == subregion_code)]['subregion1_name'].values[0]
    return region_name

def get_state_data(state, data_df, cols='new_confirmed', acc=False):
    ''' 지역의 데이터를 불러오는 함수
    Args:
      state (str): 지역의 이름
      data_df (pandas.DataFrame): 전체 데이터 테이블(프레임)
      cols (str, list): 불러올 데이터 테이블의 컬럼명, str형태일 경우 series반환, list형태일 경우 dataframe반환
      acc (bool): 누적 데이터로 만들어서 불러올 것인지 여부 (확진자 데이터의 경우 누적 데이터가 있으나, 웹의 경우 없음)

    Returns:
      padas.Series / pandas.DataFrame: 해당 지역의 데이터(cols의 타입 및 acc에 따라 리턴 타입이 다름)
    '''
    region_code = get_region_code(state)
    if acc:
        return np.add.accumulate(data_df[data_df['key']==region_code][cols].reset_index(drop=True))
    else:
        return data_df[data_df['key']==region_code][cols].reset_index(drop=True)

# %% [markdown]
# ## 사용 가능한 데이터 날짜

# %%
date_analysis = pd.DataFrame(columns=['epidemic_start', 'epidemic_end',
                                      'trends_start', 'trends_end'])

for state in states:
    region_code = get_region_code(state)
    date_analysis = pd.concat([
      date_analysis, 
      pd.DataFrame({'epidemic_start': epidemic[epidemic['key'] == region_code][:1]['date'].values,
                    'epidemic_end': epidemic[epidemic['key'] == region_code][-1:]['date'].values,
                    'trends_start': trends[trends['key'] == region_code][:1]['date'].values,
                    'trends_end': trends[trends['key'] == region_code][-1:]['date'].values,},
                   index=[state])])

date_analysis
# Out:
#                      epidemic_start epidemic_end trends_start  trends_end
# Washington               2020-01-13   2022-06-15   2020-01-01  2021-12-31
# Illinois                 2020-01-22   2022-06-15   2020-01-01  2021-12-31
# California               2020-01-22   2022-06-15   2020-01-01  2021-12-31
# Arizona                  2020-01-22   2022-06-15   2020-01-01  2021-12-31
# Massachusetts            2020-01-22   2022-06-15   2020-01-01  2021-12-31
# Wisconsin                2020-01-22   2022-06-15   2020-01-01  2021-12-31
# Texas                    2020-01-22   2022-06-15   2020-01-01  2021-12-31
# Nebraska                 2020-01-22   2022-06-15   2020-01-01  2021-12-31
# Utah                     2020-01-22   2022-06-15   2020-01-01  2021-12-31
# Oregon                   2020-01-22   2022-06-15   2020-01-01  2021-12-31
# Florida                  2020-01-22   2022-06-15   2020-01-01  2021-12-31
# New York                 2020-01-22   2022-06-15   2020-01-01  2021-12-31
# Rhode Island             2020-01-22   2022-06-15   2020-01-01  2021-12-31
# Georgia                  2020-01-22   2022-06-15   2020-01-01  2021-12-31
# New Hampshire            2020-01-22   2022-06-15   2020-01-01  2021-12-31
# North Carolina           2020-01-22   2022-06-15   2020-01-01  2021-12-31
# New Jersey               2020-01-22   2022-06-15   2020-01-01  2021-12-31
# Colorado                 2020-01-22   2022-06-15   2020-01-01  2021-12-31
# Maryland                 2020-01-22   2022-06-15   2020-01-01  2021-12-31
# Nevada                   2020-01-22   2022-06-15   2020-01-01  2021-12-31
# Tennessee                2020-01-22   2022-06-15   2020-01-01  2021-12-31
# Indiana                  2020-01-22   2022-06-15   2020-01-01  2021-12-31
# Kentucky                 2020-01-22   2022-06-15   2020-01-01  2021-12-31
# Minnesota                2020-01-22   2022-06-15   2020-01-01  2021-12-31
# Oklahoma                 2020-01-22   2022-06-15   2020-01-01  2021-12-31
# Pennsylvania             2020-01-22   2022-06-15   2020-01-01  2021-12-31
# South Carolina           2020-01-22   2022-06-15   2020-01-01  2021-12-31
# District of Columbia     2020-01-22   2022-12-30   2020-01-01  2021-12-31
# Kansas                   2020-01-22   2022-06-15   2020-01-01  2021-12-31
# Missouri                 2020-01-22   2022-06-15   2020-01-01  2021-12-31
# Vermont                  2020-01-22   2022-06-15   2020-01-01  2021-12-31
# Virginia                 2020-01-22   2022-06-15   2020-01-01  2021-12-31
# Connecticut              2020-01-22   2022-06-15   2020-01-01  2021-12-31
# Iowa                     2020-01-22   2022-06-15   2020-01-01  2021-12-31
# Louisiana                2020-01-22   2022-06-15   2020-01-01  2021-12-31
# Ohio                     2020-01-22   2022-06-15   2020-01-01  2021-12-31
# Michigan                 2020-01-22   2022-06-15   2020-01-01  2021-12-31
# South Dakota             2020-01-22   2022-06-15   2020-01-01  2021-12-31
# Arkansas                 2020-01-22   2022-06-15   2020-01-01  2021-12-31
# Delaware                 2020-01-22   2022-06-15   2020-01-01  2021-12-31
# Mississippi              2020-01-22   2022-06-15   2020-01-01  2021-12-31
# New Mexico               2020-01-22   2022-06-15   2020-01-01  2021-12-31
# North Dakota             2020-01-22   2022-06-15   2020-01-01  2021-12-31
# Wyoming                  2020-01-22   2022-06-15   2020-01-01  2021-12-31
# Maine                    2020-01-22   2022-06-15   2020-01-01  2021-12-31
# Alabama                  2020-01-22   2022-06-15   2020-01-01  2021-12-31
# Idaho                    2020-01-22   2022-06-15   2020-01-01  2021-12-31
# Montana                  2020-01-22   2022-06-15   2020-01-01  2021-12-31

# %% [markdown]
# ## 데이터 사용기간 설정, 데이터 자르기

# %%
from_date = datetime(2020, 3, 1)
to_date = datetime(2021, 12, 31)

# %%
selected_dates = []
start_date = from_date
while(start_date <= to_date):
    selected_dates.append(start_date.strftime('%Y-%m-%d'))
    start_date += timedelta(1)
epidemic = epidemic[epidemic['date'].isin(selected_dates)]
trends = trends[trends['date'].isin(selected_dates)]

# %% [markdown]
# ## 데이터에서 이상값 수정

# %%
for state in states:
    tmp_df = get_state_data(state, epidemic, ['date', 'new_confirmed'])
    roll_df = tmp_df.rolling(7).mean()

    dates = tmp_df[tmp_df['new_confirmed'] <= 0]['date']
    indices = tmp_df[tmp_df['new_confirmed'] <= 0].index

    for i, date in enumerate(dates):
        idx = epidemic[(epidemic['key']==get_region_code(state)) &
                       (epidemic['date']==date)].index
        roll_val = roll_df.loc[indices[i], 'new_confirmed']
        roll_val = 0 if np.isnan(roll_val) else roll_val
        epidemic.loc[idx, 'new_confirmed'] = roll_val

# %% [markdown]
# ## 데이터 보간

# %%
interpolated_epidemic = pd.DataFrame(columns=epidemic.columns[:3])
interpolated_epidemic

for state in tqdm(states):
    df = epidemic[epidemic['key'] == get_region_code(state)][['date', 'key', 'new_confirmed']]
    df = df.reset_index(drop=True)
    
    df.loc[df.index % 7 != 0, df.columns[2:]] = None
    df['new_confirmed'] = pd.Series(df['new_confirmed']).interpolate(method='linear')
    
    interpolated_epidemic = pd.concat([interpolated_epidemic, df])
#end for

interpolated_epidemic = interpolated_epidemic.reset_index(drop=True)
epidemic = interpolated_epidemic
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████| 48/48 [00:00<00:00, 164.83it/s]

# %%
interpolated_trends = pd.DataFrame(columns=trends.columns)

for state in tqdm(states):
    df = trends[trends['key'] == get_region_code(state)]
    df = df.reset_index(drop=True)
    
    df.loc[df.index % 7 != 0, df.columns[2:]] = None
    df_numpy = df[df.columns[2:]].to_numpy().T
    
    for i, keyword in enumerate(df.columns[2:]):
        df[keyword] = pd.Series(df_numpy[i]).interpolate(method='linear')
    #end for
    
    interpolated_trends = pd.concat([interpolated_trends, df])
#end for
interpolated_trends = interpolated_trends.reset_index(drop=True)
trends = interpolated_trends
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 48/48 [00:14<00:00,  3.30it/s]

# %% [markdown]
# ## Top 10 질병

# %%
c19Cases = {"state" : [], "cases" : []}
for state in list(states.keys()):
    c19Cases['state'].append(state)
    c19Cases['cases'].append(int(np.sum(get_state_data(state, epidemic, ['new_confirmed']).values)))
    
top10Cases = pd.DataFrame.from_dict(c19Cases)
top10Cases = top10Cases.sort_values(by="cases", ascending=False)#[:10]
top10Cases = top10Cases.reset_index(drop=True)
top10Cases
# Out:
#                    state    cases
# 0             California  6005808
# 1                Florida  3718413
# 2               New York  3632815
# 3                  Texas  2867871
# 4               Illinois  1776306
# 5           Pennsylvania  1692552
# 6                   Ohio  1685846
# 7         North Carolina  1547082
# 8                Georgia  1424281
# 9             New Jersey  1382277
# 10               Arizona  1303635
# 11              Michigan  1274232
# 12             Tennessee  1199195
# 13               Indiana  1159413
# 14              Virginia  1048534
# 15             Minnesota  1046253
# 16        South Carolina  1033314
# 17         Massachusetts  1012446
# 18             Louisiana   991828
# 19             Wisconsin   979077
# 20              Maryland   794398
# 21              Oklahoma   774585
# 22               Alabama   706487
# 23              Missouri   674378
# 24              Colorado   615054
# 25              Kentucky   572107
# 26                  Utah   568846
# 27            Washington   559507
# 28                  Iowa   486346
# 29                Nevada   478482
# 30                Kansas   473452
# 31           Connecticut   473405
# 32           Mississippi   465115
# 33              Arkansas   429472
# 34                Oregon   424812
# 35            New Mexico   310110
# 36              Nebraska   289522
# 37                 Idaho   261538
# 38          Rhode Island   207067
# 39         New Hampshire   191416
# 40               Montana   176091
# 41          South Dakota   174431
# 42              Delaware   174021
# 43          North Dakota   121168
# 44                 Maine   114992
# 45               Wyoming   109918
# 46  District of Columbia    82323
# 47               Vermont    67775

# %% [markdown]
# ## 지역 데이터 정규화

# %%
scalers = {}
scaled_epidemic = pd.DataFrame(columns=list(epidemic.columns[:2])
                               + ['new_confirmed'])

for state in states:
    scaler = MinMaxScaler()
    scaled = scaler.fit_transform(get_state_data(state, epidemic, ['new_confirmed']).values)
    tmp = pd.DataFrame(scaled, columns = ['new_confirmed'])
    tmp['date'] = get_state_data(state, epidemic, 'date')
    tmp['key'] = get_region_code(state)
    scaled_epidemic = pd.concat([scaled_epidemic, tmp])
    scalers[state] = scaler

scaled_epidemic = scaled_epidemic.reset_index(drop = True)
scaled_epidemic
# Out:
#              date    key  new_confirmed
# 0      2020-03-01  US_WA       0.000000
# 1      2020-03-02  US_WA       0.001185
# 2      2020-03-03  US_WA       0.002369
# 3      2020-03-04  US_WA       0.003554
# 4      2020-03-05  US_WA       0.004738
# ...           ...    ...            ...
# 32203  2021-12-27  US_MT       0.102314
# 32204  2021-12-28  US_MT       0.102314
# 32205  2021-12-29  US_MT       0.102314
# 32206  2021-12-30  US_MT       0.102314
# 32207  2021-12-31  US_MT       0.102314
#
# [32208 rows x 3 columns]

# %% [markdown]
# ## google trend 정규화

# %%
scaled_trends = pd.DataFrame(columns = ['key', 'date'] + [c.replace('search_trends_', '')
                                                for c in trends.columns[2:]])
for state in states:
    scaler = MinMaxScaler()
    scaled = scaler.fit_transform(get_state_data(state, trends, trends.columns[2:]).values)
    tmp = pd.DataFrame(scaled, columns = [c.replace('search_trends_', '')
                                                for c in trends.columns[2:]])
    tmp['date'] = get_state_data(state, trends, 'date')
    tmp['key'] = get_region_code(state)
    scaled_trends = pd.concat([scaled_trends, tmp])
scaled_trends = scaled_trends.reset_index(drop=True)
scaled_trends
# Out:
#          key        date  abdominal_obesity  abdominal_pain      acne  \
# 0      US_WA  2020-03-01           0.491713        0.686441  0.556818
# 1      US_WA  2020-03-02           0.481452        0.663438  0.541048
# 2      US_WA  2020-03-03           0.471192        0.640436  0.525278
# 3      US_WA  2020-03-04           0.460931        0.617433  0.509508
# 4      US_WA  2020-03-05           0.450671        0.594431  0.493738
# ...      ...         ...                ...             ...       ...
# 32203  US_MT  2021-12-27           0.077348        0.595628  0.455172
# 32204  US_MT  2021-12-28           0.077348        0.595628  0.455172
# 32205  US_MT  2021-12-29           0.077348        0.595628  0.455172
# 32206  US_MT  2021-12-30           0.077348        0.595628  0.455172
# 32207  US_MT  2021-12-31           0.077348        0.595628  0.455172
#
#        actinic_keratosis  acute_bronchitis  adrenal_crisis  ageusia  \
# 0               0.235294          0.892473        0.080000      0.0
# 1               0.218487          0.886329        0.082857      0.0
# 2               0.201681          0.880184        0.085714      0.0
# 3               0.184874          0.874040        0.088571      0.0
# 4               0.168067          0.867896        0.091429      0.0
# ...                  ...               ...             ...      ...
# 32203           0.173913          0.730769        0.000000      0.0
# 32204           0.173913          0.730769        0.000000      0.0
# 32205           0.173913          0.730769        0.000000      0.0
# 32206           0.173913          0.730769        0.000000      0.0
# 32207           0.173913          0.730769        0.000000      0.0
#
#        alcoholism  ...  visual_acuity  vomiting      wart  water_retention  \
# 0        0.145482  ...       0.538462  1.000000  0.492754         0.195122
# 1        0.135638  ...       0.538462  0.967857  0.469979         0.188153
# 2        0.125793  ...       0.538462  0.935714  0.447205         0.181185
# 3        0.115948  ...       0.538462  0.903571  0.424431         0.174216
# 4        0.106104  ...       0.538462  0.871429  0.401656         0.167247
# ...           ...  ...            ...       ...       ...              ...
# 32203    0.131213  ...       0.133333  0.692308  0.137500         0.081081
# 32204    0.131213  ...       0.133333  0.692308  0.137500         0.081081
# 32205    0.131213  ...       0.133333  0.692308  0.137500         0.081081
# 32206    0.131213  ...       0.133333  0.692308  0.137500         0.081081
# 32207    0.131213  ...       0.133333  0.692308  0.137500         0.081081
#
#        weakness  weight_gain    wheeze  xeroderma  xerostomia      yawn
# 0      0.687500     0.587097  0.552632   0.308290    0.631579  0.300000
# 1      0.705357     0.570507  0.556391   0.301628    0.631579  0.328571
# 2      0.723214     0.553917  0.560150   0.294967    0.631579  0.357143
# 3      0.741071     0.537327  0.563910   0.288305    0.631579  0.385714
# 4      0.758929     0.520737  0.567669   0.281643    0.631579  0.414286
# ...         ...          ...       ...        ...         ...       ...
# 32203  0.172414     0.251282  0.100000   0.348684    0.733333  0.000000
# 32204  0.172414     0.251282  0.100000   0.348684    0.733333  0.000000
# 32205  0.172414     0.251282  0.100000   0.348684    0.733333  0.000000
# 32206  0.172414     0.251282  0.100000   0.348684    0.733333  0.000000
# 32207  0.172414     0.251282  0.100000   0.348684    0.733333  0.000000
#
# [32208 rows x 424 columns]

# %% [markdown]
# ### 교차 상관 계수 계산
#
# 1) 타겟 지역의 누적 확진자를 base
# 2) 다른 지역의 확진자 or 해당 지역의 쿼리를 0\~28(maxlag)칸씩 오른쪽으로 shift하며 base와 상관관계  계산
# 3) 각 lag별 가장 높은 상관 관계(max_corr)와 해당 데이터의 이름(max_name)을 기록
# 4) 타겟 지역을 변경해가며 1~5)의 과정을 반복하고 테이블을 병합

# %%
MAXLAG = 28
update_force = False

# %%
xcorr_epidemic_fname = data_path + 'us_xcorr_epidemic.csv'

if os.path.exists(xcorr_epidemic_fname) and not update_force == True:
    xcorr_epidemic = pd.read_csv(xcorr_epidemic_fname)
else:
    xcorr_epidemic = pd.DataFrame()

    for state in tqdm(states, position=0):
        base = get_state_data(state, scaled_epidemic)
        regions = pd.DataFrame({state: get_state_data(state, scaled_epidemic) 
                                    for state in states})
    
        sub_epidemic = []
        for _, target_cases in regions.items():
            sub_epidemic.append(
                [base.corr(target_cases.shift(i)) for i in range(MAXLAG+1)])

        sub_epidemic = pd.DataFrame(np.array(sub_epidemic).T,
                                    columns=regions.columns)
        sub_epidemic['max_name'] = sub_epidemic[
          [sub_state for sub_state in sub_epidemic if state != sub_state]
        ].idxmax(axis=1)
        sub_epidemic['max_corr'] = sub_epidemic[
          [sub_state for sub_state in sub_epidemic if state != sub_state]
        ].max(axis=1)

        xcorr_epidemic = pd.concat([
          xcorr_epidemic,
          pd.concat([
            pd.DataFrame({'key': get_region_code(state),
                          'lag': np.arange(MAXLAG+1)}),
            sub_epidemic], axis=1)
        ])

    xcorr_epidemic = xcorr_epidemic.reset_index(drop=True)
    xcorr_epidemic.to_csv(xcorr_epidemic_fname, index=False)
xcorr_epidemic
# Out:
#         key  lag  Washington  Illinois  California   Arizona  Massachusetts  \
# 0     US_WA    0    1.000000  0.640142    0.548547  0.548336       0.517647
# 1     US_WA    1    0.993131  0.645826    0.546687  0.548219       0.515937
# 2     US_WA    2    0.975097  0.650421    0.544593  0.551544       0.513288
# 3     US_WA    3    0.948459  0.654043    0.542392  0.556990       0.509798
# 4     US_WA    4    0.915803  0.656809    0.540209  0.563232       0.505572
# ...     ...  ...         ...       ...         ...       ...            ...
# 1387  US_MT   24    0.367060  0.535234    0.213406  0.132617       0.097665
# 1388  US_MT   25    0.363019  0.522774    0.208193  0.124226       0.087108
# 1389  US_MT   26    0.358738  0.511085    0.203412  0.116039       0.076509
# 1390  US_MT   27    0.354307  0.500250    0.199061  0.107972       0.065858
# 1391  US_MT   28    0.349851  0.488551    0.195047  0.099834       0.055153
#
#       Wisconsin     Texas  Nebraska  ...  Mississippi  New Mexico  \
# 0      0.442406  0.421291  0.534291  ...     0.745176    0.555321
# 1      0.446634  0.426534  0.538606  ...     0.739030    0.556455
# 2      0.450701  0.432846  0.542271  ...     0.731788    0.557472
# 3      0.454667  0.439898  0.545389  ...     0.723316    0.558487
# 4      0.458593  0.447365  0.548061  ...     0.713477    0.559614
# ...         ...       ...       ...  ...          ...         ...
# 1387   0.712957  0.323516  0.598627  ...     0.492192    0.480247
# 1388   0.702383  0.311417  0.588179  ...     0.494590    0.468580
# 1389   0.691694  0.299353  0.577883  ...     0.496899    0.457065
# 1390   0.681030  0.287383  0.567592  ...     0.499107    0.445769
# 1391   0.670101  0.275588  0.556409  ...     0.501200    0.433604
#
#       North Dakota   Wyoming     Maine   Alabama     Idaho   Montana  \
# 0         0.387554  0.473245  0.081890  0.769372  0.665541  0.424970
# 1         0.398963  0.470997  0.076088  0.763412  0.674759  0.424036
# 2         0.410311  0.470382  0.073175  0.755888  0.686595  0.423105
# 3         0.421572  0.470981  0.072278  0.747143  0.699865  0.422136
# 4         0.432720  0.472374  0.072495  0.737523  0.713382  0.421087
# ...            ...       ...       ...       ...       ...       ...
# 1387      0.717552  0.766459  0.188519  0.429146  0.626591  0.777607
# 1388      0.708804  0.752084  0.179641  0.430681  0.620271  0.763119
# 1389      0.699672  0.737539  0.170108  0.432220  0.613663  0.748388
# 1390      0.690160  0.722848  0.159889  0.433875  0.606578  0.733446
# 1391      0.680282  0.707907  0.149001  0.435753  0.598781  0.718266
#
#        max_name  max_corr
# 0     Louisiana  0.795982
# 1     Louisiana  0.792528
# 2     Louisiana  0.787838
# 3     Louisiana  0.781870
# 4      Missouri  0.779518
# ...         ...       ...
# 1387    Wyoming  0.766459
# 1388    Wyoming  0.752084
# 1389    Wyoming  0.737539
# 1390    Wyoming  0.722848
# 1391    Wyoming  0.707907
#
# [1392 rows x 52 columns]

# %%
xcorr_trends_fname = data_path + 'us_xcorr_trends.csv'

if os.path.exists(xcorr_trends_fname) and not update_force == True:
    xcorr_trends = pd.read_csv(xcorr_trends_fname)
else:
    xcorr_trends = pd.DataFrame()

    for state in tqdm(states, position=0):
        base = get_state_data(state, scaled_epidemic)
        queries = get_state_data(state, scaled_trends, scaled_trends.columns[2:])

        sub_trends = []
        for _, target_trends in queries.items():
            sub_trends.append(
                [base.corr(target_trends.shift(i)) for i in range(MAXLAG+1)])

        sub_trends = pd.DataFrame(np.array(sub_trends).T,
                                    columns=queries.columns)
        sub_trends['max_name'] = sub_trends.idxmax(axis=1)
        sub_trends['max_corr'] = sub_trends.max(axis=1)


        xcorr_trends = pd.concat([
          xcorr_trends, 
          pd.concat([
            pd.DataFrame({'key': get_region_code(state),
                        'lag': np.arange(MAXLAG+1)}),
            sub_trends], axis=1)
          ])

    xcorr_trends = xcorr_trends.reset_index(drop=True)
    xcorr_trends.to_csv(xcorr_trends_fname, index=False)
xcorr_trends
# Out:
#         key  lag  abdominal_obesity  abdominal_pain      acne  \
# 0     US_WA    0          -0.243077        0.209276 -0.008880
# 1     US_WA    1          -0.249383        0.204992 -0.010742
# 2     US_WA    2          -0.254733        0.201294 -0.012689
# 3     US_WA    3          -0.259143        0.198224 -0.014681
# 4     US_WA    4          -0.262630        0.195824 -0.016675
# ...     ...  ...                ...             ...       ...
# 1387  US_MT   24          -0.652879        0.006639 -0.416299
# 1388  US_MT   25          -0.654586       -0.000973 -0.423838
# 1389  US_MT   26          -0.656451       -0.008710 -0.431376
# 1390  US_MT   27          -0.658486       -0.016472 -0.438915
# 1391  US_MT   28          -0.660162       -0.023881 -0.446349
#
#       actinic_keratosis  acute_bronchitis  adrenal_crisis   ageusia  \
# 0             -0.211779         -0.138324       -0.004039  0.682359
# 1             -0.208923         -0.135582       -0.008853  0.678271
# 2             -0.205182         -0.132990       -0.014599  0.674076
# 3             -0.200473         -0.130457       -0.020750  0.669602
# 4             -0.194712         -0.127892       -0.026779  0.664678
# ...                 ...               ...             ...       ...
# 1387          -0.186037         -0.009159             NaN       NaN
# 1388          -0.178643         -0.012427             NaN       NaN
# 1389          -0.171669         -0.016067             NaN       NaN
# 1390          -0.164849         -0.020103             NaN       NaN
# 1391          -0.157612         -0.024316             NaN       NaN
#
#       alcoholism  ...      wart  water_retention  weakness  weight_gain  \
# 0      -0.070868  ... -0.142557        -0.290486  0.034904    -0.115926
# 1      -0.072779  ... -0.142846        -0.293010  0.040824    -0.124565
# 2      -0.074536  ... -0.143312        -0.294598  0.049112    -0.130469
# 3      -0.075901  ... -0.143581        -0.295076  0.059217    -0.133978
# 4      -0.076634  ... -0.143268        -0.294272  0.070569    -0.135436
# ...          ...  ...       ...              ...       ...          ...
# 1387    0.022683  ... -0.323825        -0.277325 -0.109233    -0.287486
# 1388    0.016999  ... -0.319661        -0.272075 -0.109610    -0.288945
# 1389    0.011287  ... -0.314475        -0.266876 -0.110027    -0.290815
# 1390    0.005576  ... -0.308096        -0.261872 -0.110386    -0.293058
# 1391   -0.000041  ... -0.300088        -0.257377 -0.110146    -0.295450
#
#         wheeze  xeroderma  xerostomia      yawn   max_name  max_corr
# 0    -0.135807  -0.018959    0.273540 -0.199511    ageusia  0.682359
# 1    -0.136286  -0.022109    0.252107 -0.197750    ageusia  0.678271
# 2    -0.136654  -0.025768    0.231344 -0.193526  dysgeusia  0.675467
# 3    -0.137243  -0.029619    0.211936 -0.187562  dysgeusia  0.676094
# 4    -0.138382  -0.033346    0.194568 -0.180585  dysgeusia  0.675456
# ...        ...        ...         ...       ...        ...       ...
# 1387 -0.117260  -0.331406   -0.186611 -0.185607  hypoxemia  0.581717
# 1388 -0.113144  -0.341483   -0.196573 -0.190509  hypoxemia  0.573780
# 1389 -0.108219  -0.351798   -0.206291 -0.195096  hypoxemia  0.565827
# 1390 -0.102511  -0.362217   -0.215880 -0.199304  hypoxemia  0.558029
# 1391 -0.096181  -0.372240   -0.225192 -0.203161  hypoxemia  0.550418
#
# [1392 rows x 426 columns]

# %% [markdown]
# ## 데이터 슬라이싱

# %%
def DataSplit(input_data, label_data, look_back, look_ahead, split_rate=(0.6, 0.2, 0.2), teacher_force=False, time_data=None):
    #LSTM, Seq2Seq 데이터셋 만드는 함수
    def make_dataset(inputs, labels, time_dataset=None):
        window_size = look_back + look_ahead
        enc_in = []
        dec_in = []
        dec_out = []

        for i in range(len(labels) - window_size + int(teacher_force==False)):
            enc_in_select = i+look_back
            dec_in_select = enc_in_select + look_ahead
            enc_in_data = inputs[i:enc_in_select].reshape(-1, 1)
            dec_in_data = labels[enc_in_select:dec_in_select].reshape(-1, 1)
            dec_out_data = labels[enc_in_select+1:dec_in_select+1].reshape(-1, 1)

            if not time_dataset is None:
                if teacher_force == False:
                    td = time_dataset[i:enc_in_select]
                    enc_in_data = np.concatenate([enc_in_data, td], axis=1)
                else:
                    td = time_dataset[enc_in_select:dec_in_select]
                    dec_in_data = np.concatenate([dec_in_data, td], axis=1)
                #end if
            #end if

            enc_in.append(enc_in_data)
            dec_in.append(dec_in_data)
            dec_out.append(dec_out_data)
        #end for

        if teacher_force == True:
            return [np.array(enc_in), np.array(dec_in)], np.array(dec_out)
        else:
            return np.array(enc_in), np.array(dec_in)
        #end if
    #end def
    
    #학습 데이터 길이 구하기
    total_len = len(label_data)
    train_size = int(total_len * split_rate[0])
    valid_size = int(total_len * split_rate[1])
    test_size = int(total_len * split_rate[2])
    
    r = total_len - (train_size + valid_size + test_size)
    train_size += r
    
    if not time_data is None:
        trainset = make_dataset(input_data[:train_size], label_data[:train_size], time_data[:train_size])
        validset = make_dataset(input_data[train_size:train_size+valid_size], label_data[train_size:train_size+valid_size], time_data[train_size:train_size+valid_size])
        testset = make_dataset(input_data[-test_size:], label_data[-test_size:], time_data[-test_size:])
    else:
        trainset = make_dataset(input_data[:train_size], label_data[:train_size])
        validset = make_dataset(input_data[train_size:train_size+valid_size], label_data[train_size:train_size+valid_size])
        testset = make_dataset(input_data[-test_size:], label_data[-test_size:])
    #end if

    return trainset, validset, testset
#end def
    

#미국의 각 주에 대하여 다른 주와 최적의 시간차를 구함
def get_timepred_infomation(state, xcorr_data, corr_limit=0.3):
    df = xcorr_data[xcorr_data['key']==get_region_code(state)]
    df = df.reset_index(drop=True)
    dataset_indicater = {}
        
    for col in df.columns[2:-2]:
        try:
            best_step = np.argmax(df[col])
            best_corr = df[col][best_step]
            dataset_indicater[col] = {'best_step' : int(best_step), 'best_corr' : best_corr}
        except:
            pass
        #end try
    #end for

    dataset_indicater = pd.DataFrame(dataset_indicater)
    dataset_indicater_final = []
        
    for step in list(set(dataset_indicater.loc['best_step'])):
        temp = dataset_indicater.loc['best_corr'][dataset_indicater.loc['best_step'] == step]
        best_name = temp.index[temp.argmax()]
        best_corr = temp[temp.argmax()]
        if step == 0 or best_corr < corr_limit: continue

        dataset_indicater_final.append({
            'step' : step,
            'best_name' : best_name,
            'best_corr' : best_corr
        })
    #end for
    return pd.DataFrame(dataset_indicater_final)
#end def


#만들어진 시간차 정보 데이터를 통하여 데이터를 모으고 shift 시킴
def make_timedata(state, datatype='region', corr_limit=0.3):
    def _make_region_data(state):
        timepred_region = get_timepred_infomation(state, xcorr_epidemic, corr_limit)
        region_data = []

        for i in range(len(timepred_region)):
            reg_code = get_region_code(timepred_region.loc[i]['best_name'])
            step = int(timepred_region.loc[i]['step'])
            epidemic_state_data = scaled_epidemic[scaled_epidemic['key'] == reg_code]['new_confirmed']
            region_data.append(epidemic_state_data.shift(step).fillna(0).to_numpy().reshape(-1, 1))
        #end for
        
        if len(region_data) > 0: 
            return np.concatenate(region_data, axis=1)
        else:
            return None
        #end if
    #end def

    def _make_trend_data(state):
        timepred_trends = get_timepred_infomation(state, xcorr_trends, corr_limit)
        trend_data = []

        for i in range(len(timepred_trends)):
            keyword = timepred_trends.loc[i]['best_name']
            step = int(timepred_trends.loc[i]['step'])
            trends_state_data = scaled_trends[scaled_trends['key'] == get_region_code(state)]
            keyword_data = trends_state_data[keyword]
            trend_data.append(keyword_data.shift(step).fillna(0).to_numpy().reshape(-1, 1))
        #end for
        
        if len(trend_data) > 0: 
            return np.concatenate(trend_data, axis=1)
        else:
            return None
        #end if
    #end def
    
    if datatype == 'no_timedata':
        return None
    elif datatype == "region":
        region_data = _make_region_data(state)
        return region_data
    elif datatype == "trend":
        trends_data = _make_trend_data(state)
        return trends_data
    elif datatype == "region+trend":
        region_data = _make_region_data(state)
        trends_data = _make_trend_data(state)
        
        if (region_data is not None) and (trends_data is None):
            return region_data
        elif (region_data is None) and (trends_data is not None):
            return trends_data
        elif (region_data is None) and (trends_data is None):
            return None
        else:
            return np.concatenate([region_data, trends_data], axis=1)
        #end if
    else:
        raise Exception('Invalid_datatype')
    #end if
#end if

# %% [markdown]
# ## 모델 튜닝

# %%
import importlib
from collections import defaultdict
from models import seq2seq, lstm
from tcn import compiled_tcn
from utils.callbacks import EarlyStopping, ModelCheckpoint
from silence_tensorflow import silence_tensorflow
import keras_tuner as kt
import pickle

silence_tensorflow()

# %%
importlib.reload(lstm)
importlib.reload(seq2seq)
# Out:
# <module 'models.seq2seq' from 'C:\\Users\\admin\\Desktop\\미국 코로나 예측\\models\\seq2seq.py'>

# %% [markdown]
# ## 모델 평가 방법

# %%
RMSE = lambda x, y: mean_squared_error(x, y, squared=False)
MAE = mean_absolute_error
MAPE = mean_absolute_percentage_error
CORR = lambda x, y: pd.Series(tf.squeeze(x).numpy()).corr(
                    pd.Series(tf.squeeze(y).numpy()))

def evaluation(label, outputs, label_width=20):
    return {
        "RMSE": [RMSE(label[:, i], outputs[:, i]) for i in range(label_width)],
        "MAE": [MAE(label[:, i], outputs[:, i]) for i in range(label_width)],
        "MAPE": [MAPE(label[:, i], outputs[:, i]) for i in range(label_width)],
        "CORR": [CORR(label[:, i], outputs[:, i]) for i in range(label_width)]
    }

# %% [markdown]
# ## 예측할 질병

# %%
#예측할 질병 = Top 10 개 질병
target_states = top10Cases['state'][:25]

# %% [markdown]
# ## 하이퍼 파라메터 불러오기

# %%
try:
    with open("./turning/hparams.pkl","rb") as fr:
        hparams = pickle.load(fr)
    #end with
except:
    hparams = {}
#end try

# %%
hparams
# Out:
# {'California': {'lstm_no_timedata': {'units': 16,
#    'dropout': 0.1,
#    'learning_rate': 0.0353},
#   'lstm_region': {'units': 128, 'dropout': 0.3, 'learning_rate': 0.0304},
#   'lstm_trend': {'units': 64, 'dropout': 0.3, 'learning_rate': 0.0304},
#   'lstm_region+trend': {'units': 32, 'dropout': 0.1, 'learning_rate': 0.0304},
#   'seq2seq_no_timedata': {'units': 128,
#    'dropout': 0.0,
#    'learning_rate': 0.0059},
#   'seq2seq_region': {'units': 16, 'dropout': 0.1, 'learning_rate': 0.0451},
#   'seq2seq_trend': {'units': 16, 'dropout': 0.1, 'learning_rate': 0.0304},
#   'seq2seq_region+trend': {'units': 32,
#    'dropout': 0.0,
#    'learning_rate': 0.0157},
#   'tcn': {'nb_filters': 32,
#    'kernel_size': 8,
#    'dropout': 0.1,
#    'learning_rate': 0.007925000000000001}},
#  'Florida': {'lstm_no_timedata': {'units': 16,
#    'dropout': 0.0,
#    'learning_rate': 0.0402},
#   'lstm_region': {'units': 128, 'dropout': 0.0, 'learning_rate': 0.0206},
#   'lstm_trend': {'units': 128,
#    'dropout': 0.1,
#    'learning_rate': 0.025500000000000002},
#   'lstm_region+trend': {'units': 256, 'dropout': 0.0, 'learning_rate': 0.001},
#   'seq2seq_no_timedata': {'units': 16,
#    'dropout': 0.0,
#    'learning_rate': 0.025500000000000002},
#   'seq2seq_region': {'units': 64, 'dropout': 0.0, 'learning_rate': 0.0353},
#   'seq2seq_trend': {'units': 128, 'dropout': 0.0, 'learning_rate': 0.0108},
#   'seq2seq_region+trend': {'units': 32,
#    'dropout': 0.0,
#    'learning_rate': 0.0157},
#   'tcn': {'nb_filters': 16,
#    'kernel_size': 32,
#    'dropout': 0.2,
#    'learning_rate': 0.017825}},
#  'New York': {'lstm_no_timedata': {'units': 128,
#    'dropout': 0.1,
#    'learning_rate': 0.001},
#   'lstm_region': {'units': 16, 'dropout': 0.0, 'learning_rate': 0.0304},
#   'lstm_trend': {'units': 128, 'dropout': 0.1, 'learning_rate': 0.001},
#   'lstm_region+trend': {'units': 64, 'dropout': 0.1, 'learning_rate': 0.001},
#   'seq2seq_no_timedata': {'units': 32,
#    'dropout': 0.0,
#    'learning_rate': 0.0304},
#   'seq2seq_region': {'units': 32, 'dropout': 0.3, 'learning_rate': 0.0157},
#   'seq2seq_trend': {'units': 128, 'dropout': 0.3, 'learning_rate': 0.0157},
#   'seq2seq_region+trend': {'units': 16,
#    'dropout': 0.0,
#    'learning_rate': 0.0059},
#   'tcn': {'nb_filters': 32,
#    'kernel_size': 16,
#    'dropout': 0.1,
#    'learning_rate': 0.007925000000000001}},
#  'Texas': {'lstm_no_timedata': {'units': 32,
#    'dropout': 0.0,
#    'learning_rate': 0.001},
#   'lstm_region': {'units': 128, 'dropout': 0.3, 'learning_rate': 0.0304},
#   'lstm_trend': {'units': 64, 'dropout': 0.2, 'learning_rate': 0.0402},
#   'lstm_region+trend': {'units': 256,
#    'dropout': 0.0,
#    'learning_rate': 0.025500000000000002},
#   'seq2seq_no_timedata': {'units': 32,
#    'dropout': 0.0,
#    'learning_rate': 0.0304},
#   'seq2seq_region': {'units': 16, 'dropout': 0.0, 'learning_rate': 0.0108},
#   'seq2seq_trend': {'units': 16, 'dropout': 0.0, 'learning_rate': 0.0304},
#   'seq2seq_region+trend': {'units': 16,
#    'dropout': 0.3,
#    'learning_rate': 0.0353}},
#  'Illinois': {'lstm_no_timedata': {'units': 128,
#    'dropout': 0.0,
#    'learning_rate': 0.0059},
#   'lstm_region': {'units': 64, 'dropout': 0.2, 'learning_rate': 0.0108},
#   'lstm_trend': {'units': 128, 'dropout': 0.1, 'learning_rate': 0.001},
#   'lstm_region+trend': {'units': 64, 'dropout': 0.2, 'learning_rate': 0.0157},
#   'seq2seq_no_timedata': {'units': 64,
#    'dropout': 0.1,
#    'learning_rate': 0.0206},
#   'seq2seq_region': {'units': 16, 'dropout': 0.1, 'learning_rate': 0.0059},
#   'seq2seq_trend': {'units': 128, 'dropout': 0.0, 'learning_rate': 0.0108},
#   'seq2seq_region+trend': {'units': 16,
#    'dropout': 0.3,
#    'learning_rate': 0.0304}},
#  'Pennsylvania': {'lstm_no_timedata': {'units': 128,
#    'dropout': 0.2,
#    'learning_rate': 0.001},
#   'lstm_region': {'units': 16, 'dropout': 0.2, 'learning_rate': 0.0108},
#   'lstm_trend': {'units': 128, 'dropout': 0.2, 'learning_rate': 0.0108},
#   'lstm_region+trend': {'units': 128, 'dropout': 0.0, 'learning_rate': 0.0157},
#   'seq2seq_no_timedata': {'units': 32,
#    'dropout': 0.0,
#    'learning_rate': 0.025500000000000002},
#   'seq2seq_region': {'units': 16, 'dropout': 0.2, 'learning_rate': 0.0059},
#   'seq2seq_trend': {'units': 32, 'dropout': 0.0, 'learning_rate': 0.0206},
#   'seq2seq_region+trend': {'units': 256,
#    'dropout': 0.2,
#    'learning_rate': 0.0108}},
#  'Ohio': {'lstm_no_timedata': {'units': 16,
#    'dropout': 0.1,
#    'learning_rate': 0.001},
#   'lstm_region': {'units': 16, 'dropout': 0.3, 'learning_rate': 0.0059},
#   'lstm_trend': {'units': 128, 'dropout': 0.0, 'learning_rate': 0.0108},
#   'lstm_region+trend': {'units': 64, 'dropout': 0.3, 'learning_rate': 0.0206},
#   'seq2seq_no_timedata': {'units': 32,
#    'dropout': 0.0,
#    'learning_rate': 0.0402},
#   'seq2seq_region': {'units': 16, 'dropout': 0.2, 'learning_rate': 0.0059},
#   'seq2seq_trend': {'units': 32, 'dropout': 0.1, 'learning_rate': 0.0304},
#   'seq2seq_region+trend': {'units': 16,
#    'dropout': 0.2,
#    'learning_rate': 0.0157}},
#  'North Carolina': {'lstm_no_timedata': {'units': 32,
#    'dropout': 0.0,
#    'learning_rate': 0.0059},
#   'lstm_region': {'units': 16,
#    'dropout': 0.3,
#    'learning_rate': 0.025500000000000002},
#   'lstm_trend': {'units': 256, 'dropout': 0.0, 'learning_rate': 0.0206},
#   'lstm_region+trend': {'units': 256, 'dropout': 0.2, 'learning_rate': 0.0206},
#   'seq2seq_no_timedata': {'units': 16,
#    'dropout': 0.0,
#    'learning_rate': 0.0353},
#   'seq2seq_region': {'units': 16,
#    'dropout': 0.3,
#    'learning_rate': 0.025500000000000002},
#   'seq2seq_trend': {'units': 32, 'dropout': 0.1, 'learning_rate': 0.0059},
#   'seq2seq_region+trend': {'units': 128,
#    'dropout': 0.3,
#    'learning_rate': 0.0157}},
#  'Georgia': {'lstm_no_timedata': {'units': 32,
#    'dropout': 0.1,
#    'learning_rate': 0.0451},
#   'lstm_region': {'units': 16, 'dropout': 0.3, 'learning_rate': 0.0402},
#   'lstm_trend': {'units': 32, 'dropout': 0.1, 'learning_rate': 0.0353},
#   'lstm_region+trend': {'units': 64,
#    'dropout': 0.3,
#    'learning_rate': 0.025500000000000002},
#   'seq2seq_no_timedata': {'units': 64,
#    'dropout': 0.0,
#    'learning_rate': 0.0059},
#   'seq2seq_region': {'units': 128, 'dropout': 0.2, 'learning_rate': 0.0059},
#   'seq2seq_trend': {'units': 64, 'dropout': 0.1, 'learning_rate': 0.0304},
#   'seq2seq_region+trend': {'units': 16,
#    'dropout': 0.3,
#    'learning_rate': 0.0206}},
#  'New Jersey': {'lstm_no_timedata': {'units': 32,
#    'dropout': 0.1,
#    'learning_rate': 0.001},
#   'lstm_region': {'units': 32,
#    'dropout': 0.3,
#    'learning_rate': 0.025500000000000002},
#   'lstm_trend': {'units': 32, 'dropout': 0.1, 'learning_rate': 0.0108},
#   'lstm_region+trend': {'units': 16, 'dropout': 0.1, 'learning_rate': 0.0206},
#   'seq2seq_no_timedata': {'units': 128,
#    'dropout': 0.1,
#    'learning_rate': 0.0108},
#   'seq2seq_region': {'units': 128, 'dropout': 0.1, 'learning_rate': 0.001},
#   'seq2seq_trend': {'units': 256, 'dropout': 0.1, 'learning_rate': 0.001},
#   'seq2seq_region+trend': {'units': 64,
#    'dropout': 0.3,
#    'learning_rate': 0.0206}},
#  'Arizona': {'lstm_no_timedata': {'units': 64,
#    'dropout': 0.2,
#    'learning_rate': 0.025500000000000002},
#   'lstm_region': {'units': 128, 'dropout': 0.3, 'learning_rate': 0.0353},
#   'lstm_trend': {'units': 32, 'dropout': 0.1, 'learning_rate': 0.0304},
#   'lstm_region+trend': {'units': 64, 'dropout': 0.3, 'learning_rate': 0.0206},
#   'seq2seq_no_timedata': {'units': 32,
#    'dropout': 0.0,
#    'learning_rate': 0.0206},
#   'seq2seq_region': {'units': 256, 'dropout': 0.0, 'learning_rate': 0.0108},
#   'seq2seq_trend': {'units': 128, 'dropout': 0.2, 'learning_rate': 0.0059},
#   'seq2seq_region+trend': {'units': 128,
#    'dropout': 0.0,
#    'learning_rate': 0.0108}},
#  'Michigan': {'lstm_no_timedata': {'units': 128,
#    'dropout': 0.2,
#    'learning_rate': 0.0059},
#   'lstm_region': {'units': 16, 'dropout': 0.1, 'learning_rate': 0.0108},
#   'lstm_trend': {'units': 32, 'dropout': 0.0, 'learning_rate': 0.001},
#   'lstm_region+trend': {'units': 64,
#    'dropout': 0.2,
#    'learning_rate': 0.025500000000000002},
#   'seq2seq_no_timedata': {'units': 128,
#    'dropout': 0.1,
#    'learning_rate': 0.0402},
#   'seq2seq_region': {'units': 64, 'dropout': 0.1, 'learning_rate': 0.0108},
#   'seq2seq_trend': {'units': 64, 'dropout': 0.0, 'learning_rate': 0.0353},
#   'seq2seq_region+trend': {'units': 16,
#    'dropout': 0.1,
#    'learning_rate': 0.0059}},
#  'Tennessee': {'lstm_no_timedata': {'units': 32,
#    'dropout': 0.1,
#    'learning_rate': 0.0157},
#   'lstm_region': {'units': 128, 'dropout': 0.3, 'learning_rate': 0.0157},
#   'lstm_trend': {'units': 16, 'dropout': 0.2, 'learning_rate': 0.0108},
#   'lstm_region+trend': {'units': 32, 'dropout': 0.3, 'learning_rate': 0.0157},
#   'seq2seq_no_timedata': {'units': 16,
#    'dropout': 0.0,
#    'learning_rate': 0.025500000000000002},
#   'seq2seq_region': {'units': 16, 'dropout': 0.0, 'learning_rate': 0.0108},
#   'seq2seq_trend': {'units': 32, 'dropout': 0.0, 'learning_rate': 0.0451},
#   'seq2seq_region+trend': {'units': 16,
#    'dropout': 0.0,
#    'learning_rate': 0.0157}},
#  'Indiana': {'lstm_no_timedata': {'units': 128,
#    'dropout': 0.3,
#    'learning_rate': 0.001},
#   'lstm_region': {'units': 128, 'dropout': 0.1, 'learning_rate': 0.0059},
#   'lstm_trend': {'units': 32,
#    'dropout': 0.0,
#    'learning_rate': 0.025500000000000002},
#   'lstm_region+trend': {'units': 256, 'dropout': 0.2, 'learning_rate': 0.001},
#   'seq2seq_no_timedata': {'units': 128,
#    'dropout': 0.0,
#    'learning_rate': 0.0059},
#   'seq2seq_region': {'units': 64, 'dropout': 0.0, 'learning_rate': 0.0108},
#   'seq2seq_trend': {'units': 128, 'dropout': 0.0, 'learning_rate': 0.0059},
#   'seq2seq_region+trend': {'units': 32,
#    'dropout': 0.3,
#    'learning_rate': 0.0108}},
#  'Virginia': {'lstm_no_timedata': {'units': 64,
#    'dropout': 0.1,
#    'learning_rate': 0.0353},
#   'lstm_region': {'units': 64, 'dropout': 0.2, 'learning_rate': 0.0304},
#   'lstm_trend': {'units': 256, 'dropout': 0.0, 'learning_rate': 0.0108},
#   'lstm_region+trend': {'units': 16, 'dropout': 0.1, 'learning_rate': 0.0206},
#   'seq2seq_no_timedata': {'units': 32,
#    'dropout': 0.2,
#    'learning_rate': 0.0108},
#   'seq2seq_region': {'units': 32, 'dropout': 0.1, 'learning_rate': 0.0157},
#   'seq2seq_trend': {'units': 16, 'dropout': 0.3, 'learning_rate': 0.0304},
#   'seq2seq_region+trend': {'units': 16,
#    'dropout': 0.3,
#    'learning_rate': 0.0402}},
#  'Minnesota': {'lstm_no_timedata': {'units': 256,
#    'dropout': 0.0,
#    'learning_rate': 0.001},
#   'lstm_region': {'units': 64, 'dropout': 0.2, 'learning_rate': 0.001},
#   'lstm_trend': {'units': 64,
#    'dropout': 0.2,
#    'learning_rate': 0.025500000000000002},
#   'lstm_region+trend': {'units': 128, 'dropout': 0.1, 'learning_rate': 0.0157},
#   'seq2seq_no_timedata': {'units': 16,
#    'dropout': 0.1,
#    'learning_rate': 0.0059},
#   'seq2seq_region': {'units': 64, 'dropout': 0.0, 'learning_rate': 0.0059},
#   'seq2seq_trend': {'units': 32, 'dropout': 0.2, 'learning_rate': 0.0059},
#   'seq2seq_region+trend': {'units': 64,
#    'dropout': 0.0,
#    'learning_rate': 0.0059}},
#  'South Carolina': {'lstm_no_timedata': {'units': 128,
#    'dropout': 0.2,
#    'learning_rate': 0.0059},
#   'lstm_region': {'units': 128, 'dropout': 0.3, 'learning_rate': 0.0304},
#   'lstm_trend': {'units': 16, 'dropout': 0.0, 'learning_rate': 0.0353},
#   'lstm_region+trend': {'units': 64, 'dropout': 0.3, 'learning_rate': 0.0157},
#   'seq2seq_no_timedata': {'units': 16,
#    'dropout': 0.1,
#    'learning_rate': 0.0108},
#   'seq2seq_region': {'units': 16, 'dropout': 0.1, 'learning_rate': 0.0402},
#   'seq2seq_trend': {'units': 16, 'dropout': 0.0, 'learning_rate': 0.0402},
#   'seq2seq_region+trend': {'units': 32,
#    'dropout': 0.2,
#    'learning_rate': 0.025500000000000002}},
#  'Massachusetts': {'lstm_no_timedata': {'units': 16,
#    'dropout': 0.1,
#    'learning_rate': 0.001},
#   'lstm_region': {'units': 64, 'dropout': 0.0, 'learning_rate': 0.0059},
#   'lstm_trend': {'units': 32, 'dropout': 0.2, 'learning_rate': 0.0059},
#   'lstm_region+trend': {'units': 256, 'dropout': 0.3, 'learning_rate': 0.0108},
#   'seq2seq_no_timedata': {'units': 32,
#    'dropout': 0.3,
#    'learning_rate': 0.0206},
#   'seq2seq_region': {'units': 32, 'dropout': 0.0, 'learning_rate': 0.0108},
#   'seq2seq_trend': {'units': 64, 'dropout': 0.1, 'learning_rate': 0.0353},
#   'seq2seq_region+trend': {'units': 16,
#    'dropout': 0.2,
#    'learning_rate': 0.0206}},
#  'Louisiana': {'lstm_no_timedata': {'units': 32,
#    'dropout': 0.1,
#    'learning_rate': 0.0304},
#   'lstm_region': {'units': 256, 'dropout': 0.2, 'learning_rate': 0.0304},
#   'lstm_trend': {'units': 32, 'dropout': 0.0, 'learning_rate': 0.0353},
#   'lstm_region+trend': {'units': 128, 'dropout': 0.0, 'learning_rate': 0.001},
#   'seq2seq_no_timedata': {'units': 16,
#    'dropout': 0.0,
#    'learning_rate': 0.0402},
#   'seq2seq_region': {'units': 16, 'dropout': 0.0, 'learning_rate': 0.0206},
#   'seq2seq_trend': {'units': 32, 'dropout': 0.0, 'learning_rate': 0.05},
#   'seq2seq_region+trend': {'units': 16,
#    'dropout': 0.0,
#    'learning_rate': 0.025500000000000002}},
#  'Wisconsin': {'lstm_no_timedata': {'units': 16,
#    'dropout': 0.3,
#    'learning_rate': 0.001},
#   'lstm_region': {'units': 256, 'dropout': 0.2, 'learning_rate': 0.0059},
#   'lstm_trend': {'units': 64, 'dropout': 0.0, 'learning_rate': 0.0402},
#   'lstm_region+trend': {'units': 256, 'dropout': 0.1, 'learning_rate': 0.0206},
#   'seq2seq_no_timedata': {'units': 128,
#    'dropout': 0.0,
#    'learning_rate': 0.0059},
#   'seq2seq_region': {'units': 64, 'dropout': 0.1, 'learning_rate': 0.0157},
#   'seq2seq_trend': {'units': 128, 'dropout': 0.2, 'learning_rate': 0.0059},
#   'seq2seq_region+trend': {'units': 64,
#    'dropout': 0.0,
#    'learning_rate': 0.0108}},
#  'Maryland': {'lstm_no_timedata': {'units': 128,
#    'dropout': 0.3,
#    'learning_rate': 0.0206},
#   'lstm_region': {'units': 256, 'dropout': 0.0, 'learning_rate': 0.001},
#   'lstm_trend': {'units': 128, 'dropout': 0.1, 'learning_rate': 0.0206},
#   'lstm_region+trend': {'units': 32, 'dropout': 0.0, 'learning_rate': 0.0304},
#   'seq2seq_no_timedata': {'units': 128,
#    'dropout': 0.2,
#    'learning_rate': 0.001},
#   'seq2seq_region': {'units': 64, 'dropout': 0.2, 'learning_rate': 0.0157},
#   'seq2seq_trend': {'units': 128, 'dropout': 0.1, 'learning_rate': 0.0157},
#   'seq2seq_region+trend': {'units': 16,
#    'dropout': 0.1,
#    'learning_rate': 0.0402}},
#  'Oklahoma': {'lstm_no_timedata': {'units': 128,
#    'dropout': 0.2,
#    'learning_rate': 0.0059},
#   'lstm_region': {'units': 256, 'dropout': 0.0, 'learning_rate': 0.001},
#   'lstm_trend': {'units': 64, 'dropout': 0.1, 'learning_rate': 0.0157},
#   'lstm_region+trend': {'units': 256, 'dropout': 0.0, 'learning_rate': 0.0157},
#   'seq2seq_no_timedata': {'units': 128,
#    'dropout': 0.1,
#    'learning_rate': 0.0059},
#   'seq2seq_region': {'units': 128, 'dropout': 0.0, 'learning_rate': 0.0059},
#   'seq2seq_trend': {'units': 32, 'dropout': 0.1, 'learning_rate': 0.0059},
#   'seq2seq_region+trend': {'units': 256,
#    'dropout': 0.1,
#    'learning_rate': 0.0108}},
#  'Alabama': {'lstm_no_timedata': {'units': 16,
#    'dropout': 0.2,
#    'learning_rate': 0.0353},
#   'lstm_region': {'units': 128, 'dropout': 0.0, 'learning_rate': 0.05},
#   'lstm_trend': {'units': 64, 'dropout': 0.2, 'learning_rate': 0.0304},
#   'lstm_region+trend': {'units': 32, 'dropout': 0.3, 'learning_rate': 0.0451},
#   'seq2seq_no_timedata': {'units': 16,
#    'dropout': 0.1,
#    'learning_rate': 0.025500000000000002},
#   'seq2seq_region': {'units': 64, 'dropout': 0.1, 'learning_rate': 0.0157},
#   'seq2seq_trend': {'units': 64, 'dropout': 0.0, 'learning_rate': 0.0108},
#   'seq2seq_region+trend': {'units': 32,
#    'dropout': 0.0,
#    'learning_rate': 0.0157}},
#  'Missouri': {'lstm_no_timedata': {'units': 128,
#    'dropout': 0.1,
#    'learning_rate': 0.0157},
#   'lstm_region': {'units': 128, 'dropout': 0.2, 'learning_rate': 0.0157},
#   'lstm_trend': {'units': 256, 'dropout': 0.0, 'learning_rate': 0.0157},
#   'lstm_region+trend': {'units': 64, 'dropout': 0.0, 'learning_rate': 0.0451},
#   'seq2seq_no_timedata': {'units': 64,
#    'dropout': 0.0,
#    'learning_rate': 0.0059},
#   'seq2seq_region': {'units': 64, 'dropout': 0.2, 'learning_rate': 0.0108},
#   'seq2seq_trend': {'units': 16, 'dropout': 0.1, 'learning_rate': 0.0206},
#   'seq2seq_region+trend': {'units': 16,
#    'dropout': 0.1,
#    'learning_rate': 0.0108}},
#  'Colorado': {'lstm_no_timedata': {'units': 256,
#    'dropout': 0.0,
#    'learning_rate': 0.001},
#   'lstm_region': {'units': 256, 'dropout': 0.3, 'learning_rate': 0.001},
#   'lstm_trend': {'units': 128, 'dropout': 0.3, 'learning_rate': 0.0108},
#   'lstm_region+trend': {'units': 16,
#    'dropout': 0.0,
#    'learning_rate': 0.025500000000000002},
#   'seq2seq_no_timedata': {'units': 32,
#    'dropout': 0.1,
#    'learning_rate': 0.0059},
#   'seq2seq_region': {'units': 64, 'dropout': 0.0, 'learning_rate': 0.0304},
#   'seq2seq_trend': {'units': 32, 'dropout': 0.3, 'learning_rate': 0.0206},
#   'seq2seq_region+trend': {'units': 64,
#    'dropout': 0.3,
#    'learning_rate': 0.001}}}

# %% [markdown]
# ## 튜닝 파라메터

# %%
max_epochs = 20
epochs = 20
batch_size = 20

look_back = 28
look_ahead = 28

corr_limit = 0.5

dataset_split = (0.6, 0.2, 0.2)

# %% [markdown]
# ## 튜닝할 모델

# %%
from tensorflow.keras.optimizers import Adam

class model_lstm(kt.HyperModel):
    def build(self, hp):
        units = hp.Choice('units', [16, 32, 64, 128, 256])
        dropout = hp.Choice('dropout', [0.0, 0.1, 0.2, 0.3])
        learning_rate = hp.Float('learning_rate', min_value=0.001, max_value=0.05, step=0.0049)
        
        lstm_model = tf.keras.Sequential([
            tf.keras.layers.LSTM(units, dropout=dropout),
            tf.keras.layers.Dense(look_ahead),
            tf.keras.layers.Reshape((look_ahead, 1)),
        ])
        
        lstm_model.compile(loss='mse', optimizer=Adam(learning_rate=learning_rate))
        return lstm_model
    #end def
#end class

class model_seq2seq(kt.HyperModel):
    def __init__(self, feature_count):
        self.feature_count = feature_count
    #end def
    
    def build(self, hp):
        units = hp.Choice('units', [16, 32, 64, 128, 256])
        dropout = hp.Choice('dropout', [0.0, 0.1, 0.2, 0.3])
        learning_rate = hp.Float('learning_rate', min_value=0.001, max_value=0.05, step=0.0049)
        seq2seq_model = seq2seq.get_model(units, look_back, look_ahead, self.feature_count, dropout, learning_rate=learning_rate)
        return seq2seq_model
    #end def
#end class

class model_tcn(kt.HyperModel):
    def __init__(self, feature_count):
        self.feature_count = feature_count
    #end def
    
    def build(self, hp):
        nb_filters = hp.Choice('nb_filters', [4, 8, 16, 32])
        kernel_size = hp.Choice('kernel_size', [4, 8, 16, 32])
        dropout = hp.Choice('dropout', [0.0, 0.1, 0.2, 0.3])
        learning_rate = learning_rate = hp.Float('learning_rate', min_value=0.0005, max_value=0.05, step=0.002475)
        
        return compiled_tcn(
            return_sequences=False,
            num_feat=self.feature_count,
            nb_filters=nb_filters,
            num_classes=0,
            kernel_size=kernel_size,
            dilations=[2 ** i for i in range(9)], # 2, 4, 8, 16, 32...
            nb_stacks=1,
            max_len=look_back,
            use_skip_connections=True,
            regression=True,
            dropout_rate=dropout,
            output_len=look_ahead,
            lr=learning_rate,
        )
    #end def
#end class

# %% [markdown]
# ## LSTM 튜닝

# %%
model_name = 'lstm'

for state in target_states:
    if not state in list(hparams.keys()): hparams[state] = {}
    for additional_data in ['no_timedata', 'region', 'trend', 'region+trend']:
        #현제 진행하고 있는 주 이름, 진행상황 표시
        progress = '[' + str(list(hparams.keys()).index(state) + 1) + '/' + str(len(target_states)) + ']'
        print('='*20, state + "_" + additional_data + ' ' + progress, '='*20)
        
        #저장할 파일 이름 정의
        save_name = state + "_" + model_name + "_" + additional_data
    
        #주 데이터 구하기
        states_data = scaled_epidemic[scaled_epidemic['key'] == get_region_code(state)]['new_confirmed'].to_numpy()
        
        #시간데이터 사용하는 경우에만 넣기
        if not additional_data == 'no_timedata':
            time_data = make_timedata(state, datatype=additional_data, corr_limit=corr_limit)
            
            #시간데이터가 corr_limit 때문에 0인 경우 시간데이터를 사용하지 않음
            if time_data is None:
                feature_count = 1
            else:
                feature_count = time_data.shape[1] + 1
            #end if
        else:
            time_data = None
            feature_count = 1
        #end if

        #데이터 생성
        train, valid, test = DataSplit(
            states_data, 
            states_data, 
            look_back, 
            look_ahead, 
            split_rate=dataset_split, 
            time_data=time_data,
            teacher_force=False, 
        )
        
        #케라스 튜너
        tuner = kt.Hyperband(
            model_lstm(), 
            objective = 'val_loss', 
            max_epochs=20,
            directory="./turning",
            project_name = save_name
        )
        
        #하이퍼 파라메터 검색
        tuner.search(
            train[0],
            train[1], 
            validation_data=(valid[0], valid[1]),
            batch_size=batch_size,
            epochs=20,
            shuffle = False, 
            verbose = 0, 
            workers = 4,
        )
        
        #최적 파라메터 저장
        best_hps = tuner.get_best_hyperparameters()[0]
        hparams[state][model_name + "_" + additional_data] = {
            'units' : best_hps.get('units'),
            'dropout' : best_hps.get('dropout'),
            'learning_rate' : best_hps.get('learning_rate')
        }
        
        #저장
        with open("./turning/hparams.pkl","wb") as fw:
            pickle.dump(hparams, fw)
        #end with
            
        #클리어 세션
        tf.keras.backend.clear_session() 
        print(hparams[state][model_name + "_" + additional_data])
        print()
    #end for
#end for
# Out:
# ==================== California_no_timedata [1/25] ====================
# {'units': 16, 'dropout': 0.1, 'learning_rate': 0.0353}
#
# ==================== California_region [1/25] ====================
# {'units': 128, 'dropout': 0.3, 'learning_rate': 0.0304}
#
# ==================== California_trend [1/25] ====================
# {'units': 64, 'dropout': 0.3, 'learning_rate': 0.0304}
#
# ==================== California_region+trend [1/25] ====================
# {'units': 32, 'dropout': 0.1, 'learning_rate': 0.0304}
#
# ==================== Florida_no_timedata [2/25] ====================
# {'units': 16, 'dropout': 0.0, 'learning_rate': 0.0402}
#
# ==================== Florida_region [2/25] ====================
# {'units': 128, 'dropout': 0.0, 'learning_rate': 0.0206}
#
# ==================== Florida_trend [2/25] ====================
# {'units': 128, 'dropout': 0.1, 'learning_rate': 0.025500000000000002}
#
# ==================== Florida_region+trend [2/25] ====================
# {'units': 256, 'dropout': 0.0, 'learning_rate': 0.001}
#
# ==================== New York_no_timedata [3/25] ====================
# {'units': 128, 'dropout': 0.1, 'learning_rate': 0.001}
#
# ==================== New York_region [3/25] ====================
# {'units': 16, 'dropout': 0.0, 'learning_rate': 0.0304}
#
# ==================== New York_trend [3/25] ====================
# {'units': 128, 'dropout': 0.1, 'learning_rate': 0.001}
#
# ==================== New York_region+trend [3/25] ====================
# {'units': 64, 'dropout': 0.1, 'learning_rate': 0.001}
#
# ==================== Texas_no_timedata [4/25] ====================
# {'units': 32, 'dropout': 0.0, 'learning_rate': 0.001}
#
# ==================== Texas_region [4/25] ====================
# {'units': 128, 'dropout': 0.3, 'learning_rate': 0.0304}
#
# ==================== Texas_trend [4/25] ====================
# {'units': 64, 'dropout': 0.2, 'learning_rate': 0.0402}
#
# ==================== Texas_region+trend [4/25] ====================
# {'units': 256, 'dropout': 0.0, 'learning_rate': 0.025500000000000002}
#
# ==================== Illinois_no_timedata [5/25] ====================
# {'units': 128, 'dropout': 0.0, 'learning_rate': 0.0059}
#
# ==================== Illinois_region [5/25] ====================
# {'units': 64, 'dropout': 0.2, 'learning_rate': 0.0108}
#
# ==================== Illinois_trend [5/25] ====================
# {'units': 128, 'dropout': 0.1, 'learning_rate': 0.001}
#
# ==================== Illinois_region+trend [5/25] ====================
# {'units': 64, 'dropout': 0.2, 'learning_rate': 0.0157}
#
# ==================== Pennsylvania_no_timedata [6/25] ====================
# {'units': 128, 'dropout': 0.2, 'learning_rate': 0.001}
#
# ==================== Pennsylvania_region [6/25] ====================
# {'units': 16, 'dropout': 0.2, 'learning_rate': 0.0108}
#
# ==================== Pennsylvania_trend [6/25] ====================
# {'units': 128, 'dropout': 0.2, 'learning_rate': 0.0108}
#
# ==================== Pennsylvania_region+trend [6/25] ====================
# {'units': 128, 'dropout': 0.0, 'learning_rate': 0.0157}
#
# ==================== Ohio_no_timedata [7/25] ====================
# {'units': 16, 'dropout': 0.1, 'learning_rate': 0.001}
#
# ==================== Ohio_region [7/25] ====================
# {'units': 16, 'dropout': 0.3, 'learning_rate': 0.0059}
#
# ==================== Ohio_trend [7/25] ====================
# {'units': 128, 'dropout': 0.0, 'learning_rate': 0.0108}
#
# ==================== Ohio_region+trend [7/25] ====================
# {'units': 64, 'dropout': 0.3, 'learning_rate': 0.0206}
#
# ==================== North Carolina_no_timedata [8/25] ====================
# {'units': 32, 'dropout': 0.0, 'learning_rate': 0.0059}
#
# ==================== North Carolina_region [8/25] ====================
# {'units': 16, 'dropout': 0.3, 'learning_rate': 0.025500000000000002}
#
# ==================== North Carolina_trend [8/25] ====================
# {'units': 256, 'dropout': 0.0, 'learning_rate': 0.0206}
#
# ==================== North Carolina_region+trend [8/25] ====================
# {'units': 256, 'dropout': 0.2, 'learning_rate': 0.0206}
#
# ==================== Georgia_no_timedata [9/25] ====================
# {'units': 32, 'dropout': 0.1, 'learning_rate': 0.0451}
#
# ==================== Georgia_region [9/25] ====================
# {'units': 16, 'dropout': 0.3, 'learning_rate': 0.0402}
#
# ==================== Georgia_trend [9/25] ====================
# {'units': 32, 'dropout': 0.1, 'learning_rate': 0.0353}
#
# ==================== Georgia_region+trend [9/25] ====================
# {'units': 64, 'dropout': 0.3, 'learning_rate': 0.025500000000000002}
#
# ==================== New Jersey_no_timedata [10/25] ====================
# {'units': 32, 'dropout': 0.1, 'learning_rate': 0.001}
#
# ==================== New Jersey_region [10/25] ====================
# {'units': 32, 'dropout': 0.3, 'learning_rate': 0.025500000000000002}
#
# ==================== New Jersey_trend [10/25] ====================
# {'units': 32, 'dropout': 0.1, 'learning_rate': 0.0108}
#
# ==================== New Jersey_region+trend [10/25] ====================
# {'units': 16, 'dropout': 0.1, 'learning_rate': 0.0206}
#
# ==================== Arizona_no_timedata [11/25] ====================
# {'units': 64, 'dropout': 0.2, 'learning_rate': 0.025500000000000002}
#
# ==================== Arizona_region [11/25] ====================
# {'units': 128, 'dropout': 0.3, 'learning_rate': 0.0353}
#
# ==================== Arizona_trend [11/25] ====================
# {'units': 32, 'dropout': 0.1, 'learning_rate': 0.0304}
#
# ==================== Arizona_region+trend [11/25] ====================
# {'units': 64, 'dropout': 0.3, 'learning_rate': 0.0206}
#
# ==================== Michigan_no_timedata [12/25] ====================
# {'units': 128, 'dropout': 0.2, 'learning_rate': 0.0059}
#
# ==================== Michigan_region [12/25] ====================
# {'units': 16, 'dropout': 0.1, 'learning_rate': 0.0108}
#
# ==================== Michigan_trend [12/25] ====================
# {'units': 32, 'dropout': 0.0, 'learning_rate': 0.001}
#
# ==================== Michigan_region+trend [12/25] ====================
# {'units': 64, 'dropout': 0.2, 'learning_rate': 0.025500000000000002}
#
# ==================== Tennessee_no_timedata [13/25] ====================
# {'units': 32, 'dropout': 0.1, 'learning_rate': 0.0157}
#
# ==================== Tennessee_region [13/25] ====================
# {'units': 128, 'dropout': 0.3, 'learning_rate': 0.0157}
#
# ==================== Tennessee_trend [13/25] ====================
# {'units': 16, 'dropout': 0.2, 'learning_rate': 0.0108}
#
# ==================== Tennessee_region+trend [13/25] ====================
# {'units': 32, 'dropout': 0.3, 'learning_rate': 0.0157}
#
# ==================== Indiana_no_timedata [14/25] ====================
# {'units': 128, 'dropout': 0.3, 'learning_rate': 0.001}
#
# ==================== Indiana_region [14/25] ====================
# {'units': 128, 'dropout': 0.1, 'learning_rate': 0.0059}
#
# ==================== Indiana_trend [14/25] ====================
# {'units': 32, 'dropout': 0.0, 'learning_rate': 0.025500000000000002}
#
# ==================== Indiana_region+trend [14/25] ====================
# {'units': 256, 'dropout': 0.2, 'learning_rate': 0.001}
#
# ==================== Virginia_no_timedata [15/25] ====================
# {'units': 64, 'dropout': 0.1, 'learning_rate': 0.0353}
#
# ==================== Virginia_region [15/25] ====================
# {'units': 64, 'dropout': 0.2, 'learning_rate': 0.0304}
#
# ==================== Virginia_trend [15/25] ====================
# {'units': 256, 'dropout': 0.0, 'learning_rate': 0.0108}
#
# ==================== Virginia_region+trend [15/25] ====================
# {'units': 16, 'dropout': 0.1, 'learning_rate': 0.0206}
#
# ==================== Minnesota_no_timedata [16/25] ====================
# {'units': 256, 'dropout': 0.0, 'learning_rate': 0.001}
#
# ==================== Minnesota_region [16/25] ====================
# {'units': 64, 'dropout': 0.2, 'learning_rate': 0.001}
#
# ==================== Minnesota_trend [16/25] ====================
# {'units': 64, 'dropout': 0.2, 'learning_rate': 0.025500000000000002}
#
# ==================== Minnesota_region+trend [16/25] ====================
# {'units': 128, 'dropout': 0.1, 'learning_rate': 0.0157}
#
# ==================== South Carolina_no_timedata [17/25] ====================
# {'units': 128, 'dropout': 0.2, 'learning_rate': 0.0059}
#
# ==================== South Carolina_region [17/25] ====================
# {'units': 128, 'dropout': 0.3, 'learning_rate': 0.0304}
#
# ==================== South Carolina_trend [17/25] ====================
# {'units': 16, 'dropout': 0.0, 'learning_rate': 0.0353}
#
# ==================== South Carolina_region+trend [17/25] ====================
# {'units': 64, 'dropout': 0.3, 'learning_rate': 0.0157}
#
# ==================== Massachusetts_no_timedata [18/25] ====================
# {'units': 16, 'dropout': 0.1, 'learning_rate': 0.001}
#
# ==================== Massachusetts_region [18/25] ====================
# {'units': 64, 'dropout': 0.0, 'learning_rate': 0.0059}
#
# ==================== Massachusetts_trend [18/25] ====================
# {'units': 32, 'dropout': 0.2, 'learning_rate': 0.0059}
#
# ==================== Massachusetts_region+trend [18/25] ====================
# {'units': 256, 'dropout': 0.3, 'learning_rate': 0.0108}
#
# ==================== Louisiana_no_timedata [19/25] ====================
# {'units': 32, 'dropout': 0.1, 'learning_rate': 0.0304}
#
# ==================== Louisiana_region [19/25] ====================
# {'units': 256, 'dropout': 0.2, 'learning_rate': 0.0304}
#
# ==================== Louisiana_trend [19/25] ====================
# {'units': 32, 'dropout': 0.0, 'learning_rate': 0.0353}
#
# ==================== Louisiana_region+trend [19/25] ====================
# {'units': 128, 'dropout': 0.0, 'learning_rate': 0.001}
#
# ==================== Wisconsin_no_timedata [20/25] ====================
# {'units': 16, 'dropout': 0.3, 'learning_rate': 0.001}
#
# ==================== Wisconsin_region [20/25] ====================
# {'units': 256, 'dropout': 0.2, 'learning_rate': 0.0059}
#
# ==================== Wisconsin_trend [20/25] ====================
# {'units': 64, 'dropout': 0.0, 'learning_rate': 0.0402}
#
# ==================== Wisconsin_region+trend [20/25] ====================
# {'units': 256, 'dropout': 0.1, 'learning_rate': 0.0206}
#
# ==================== Maryland_no_timedata [21/25] ====================
# {'units': 128, 'dropout': 0.3, 'learning_rate': 0.0206}
#
# ==================== Maryland_region [21/25] ====================
# {'units': 256, 'dropout': 0.0, 'learning_rate': 0.001}
#
# ==================== Maryland_trend [21/25] ====================
# {'units': 128, 'dropout': 0.1, 'learning_rate': 0.0206}
#
# ==================== Maryland_region+trend [21/25] ====================
# {'units': 32, 'dropout': 0.0, 'learning_rate': 0.0304}
#
# ==================== Oklahoma_no_timedata [22/25] ====================
# {'units': 128, 'dropout': 0.2, 'learning_rate': 0.0059}
#
# ==================== Oklahoma_region [22/25] ====================
# {'units': 256, 'dropout': 0.0, 'learning_rate': 0.001}
#
# ==================== Oklahoma_trend [22/25] ====================
# {'units': 64, 'dropout': 0.1, 'learning_rate': 0.0157}
#
# ==================== Oklahoma_region+trend [22/25] ====================
# {'units': 256, 'dropout': 0.0, 'learning_rate': 0.0157}
#
# ==================== Alabama_no_timedata [23/25] ====================
# {'units': 16, 'dropout': 0.2, 'learning_rate': 0.0353}
#
# ==================== Alabama_region [23/25] ====================
# {'units': 128, 'dropout': 0.0, 'learning_rate': 0.05}
#
# ==================== Alabama_trend [23/25] ====================
# {'units': 64, 'dropout': 0.2, 'learning_rate': 0.0304}
#
# ==================== Alabama_region+trend [23/25] ====================
# {'units': 32, 'dropout': 0.3, 'learning_rate': 0.0451}
#
# ==================== Missouri_no_timedata [24/25] ====================
# {'units': 128, 'dropout': 0.1, 'learning_rate': 0.0157}
#
# ==================== Missouri_region [24/25] ====================
# {'units': 128, 'dropout': 0.2, 'learning_rate': 0.0157}
#
# ==================== Missouri_trend [24/25] ====================
# {'units': 256, 'dropout': 0.0, 'learning_rate': 0.0157}
#
# ==================== Missouri_region+trend [24/25] ====================
# {'units': 64, 'dropout': 0.0, 'learning_rate': 0.0451}
#
# ==================== Colorado_no_timedata [25/25] ====================
# {'units': 256, 'dropout': 0.0, 'learning_rate': 0.001}
#
# ==================== Colorado_region [25/25] ====================
# {'units': 256, 'dropout': 0.3, 'learning_rate': 0.001}
#
# ==================== Colorado_trend [25/25] ====================
# {'units': 128, 'dropout': 0.3, 'learning_rate': 0.0108}
#
# ==================== Colorado_region+trend [25/25] ====================
# {'units': 16, 'dropout': 0.0, 'learning_rate': 0.025500000000000002}

# %% [markdown]
# ## Seq2Seq 튜닝

# %%
model_name = 'seq2seq'

for state in target_states:
    if not state in list(hparams.keys()): hparams[state] = {}
    for additional_data in ['no_timedata', 'region', 'trend', 'region+trend']:
        #현제 진행하고 있는 주 이름, 진행상황 표시
        progress = '[' + str(list(hparams.keys()).index(state) + 1) + '/' + str(len(target_states)) + ']'
        print('='*20, state + "_" + additional_data + ' ' + progress, '='*20)
        
        #저장할 파일 이름 정의
        save_name = state + "_" + model_name + "_" + additional_data
    
        #주 데이터 구하기
        states_data = scaled_epidemic[scaled_epidemic['key'] == get_region_code(state)]['new_confirmed'].to_numpy()
        
        #시간데이터 사용하는 경우에만 넣기
        if not additional_data == 'no_timedata':
            time_data = make_timedata(state, datatype=additional_data, corr_limit=corr_limit)
            
            #시간데이터가 corr_limit 때문에 0인 경우 시간데이터를 사용하지 않음
            if time_data is None:
                feature_count = 1
            else:
                feature_count = time_data.shape[1] + 1
            #end if
        else:
            time_data = None
            feature_count = 1
        #end if

        #데이터 생성
        train, valid, test = DataSplit(
            states_data, 
            states_data, 
            look_back, 
            look_ahead, 
            split_rate=dataset_split, 
            time_data=time_data,
            teacher_force=True, 
        )
        
        #케라스 튜너
        tuner = kt.Hyperband(
            model_seq2seq(feature_count), 
            objective = 'val_loss', 
            max_epochs=20,
            directory="./turning",
            project_name = save_name
        )
        
        #하이퍼 파라메터 검색
        tuner.search(
            train[0],
            train[1], 
            validation_data=(valid[0], valid[1]),
            batch_size=batch_size,
            epochs=20,
            shuffle = False, 
            verbose = 0, 
            workers = 4,
        )
        
        #최적 파라메터 저장
        best_hps = tuner.get_best_hyperparameters()[0]
        hparams[state][model_name + "_" + additional_data] = {
            'units' : best_hps.get('units'),
            'dropout' : best_hps.get('dropout'),
            'learning_rate' : best_hps.get('learning_rate')
        }
        
        #저장
        with open("./turning/hparams.pkl","wb") as fw:
            pickle.dump(hparams, fw)
        #end with
            
        #클리어 세션
        tf.keras.backend.clear_session() 
        print(hparams[state][model_name + "_" + additional_data])
        print()
    #end for
#end for
# Out:
# ==================== California_no_timedata [1/25] ====================
# {'units': 128, 'dropout': 0.0, 'learning_rate': 0.0059}
#
# ==================== California_region [1/25] ====================
# {'units': 16, 'dropout': 0.1, 'learning_rate': 0.0451}
#
# ==================== California_trend [1/25] ====================
# {'units': 16, 'dropout': 0.1, 'learning_rate': 0.0304}
#
# ==================== California_region+trend [1/25] ====================
# {'units': 32, 'dropout': 0.0, 'learning_rate': 0.0157}
#
# ==================== Florida_no_timedata [2/25] ====================
# {'units': 16, 'dropout': 0.0, 'learning_rate': 0.025500000000000002}
#
# ==================== Florida_region [2/25] ====================
# {'units': 64, 'dropout': 0.0, 'learning_rate': 0.0353}
#
# ==================== Florida_trend [2/25] ====================
# {'units': 128, 'dropout': 0.0, 'learning_rate': 0.0108}
#
# ==================== Florida_region+trend [2/25] ====================
# {'units': 32, 'dropout': 0.0, 'learning_rate': 0.0157}
#
# ==================== New York_no_timedata [3/25] ====================
# {'units': 32, 'dropout': 0.0, 'learning_rate': 0.0304}
#
# ==================== New York_region [3/25] ====================
# {'units': 32, 'dropout': 0.3, 'learning_rate': 0.0157}
#
# ==================== New York_trend [3/25] ====================
# {'units': 128, 'dropout': 0.3, 'learning_rate': 0.0157}
#
# ==================== New York_region+trend [3/25] ====================
# {'units': 16, 'dropout': 0.0, 'learning_rate': 0.0059}
#
# ==================== Texas_no_timedata [4/25] ====================
# {'units': 32, 'dropout': 0.0, 'learning_rate': 0.0304}
#
# ==================== Texas_region [4/25] ====================
# {'units': 16, 'dropout': 0.0, 'learning_rate': 0.0108}
#
# ==================== Texas_trend [4/25] ====================
# {'units': 16, 'dropout': 0.0, 'learning_rate': 0.0304}
#
# ==================== Texas_region+trend [4/25] ====================
# {'units': 16, 'dropout': 0.3, 'learning_rate': 0.0353}
#
# ==================== Illinois_no_timedata [5/25] ====================
# {'units': 64, 'dropout': 0.1, 'learning_rate': 0.0206}
#
# ==================== Illinois_region [5/25] ====================
# {'units': 16, 'dropout': 0.1, 'learning_rate': 0.0059}
#
# ==================== Illinois_trend [5/25] ====================
# {'units': 128, 'dropout': 0.0, 'learning_rate': 0.0108}
#
# ==================== Illinois_region+trend [5/25] ====================
# {'units': 16, 'dropout': 0.3, 'learning_rate': 0.0304}
#
# ==================== Pennsylvania_no_timedata [6/25] ====================
# {'units': 32, 'dropout': 0.0, 'learning_rate': 0.025500000000000002}
#
# ==================== Pennsylvania_region [6/25] ====================
# {'units': 16, 'dropout': 0.2, 'learning_rate': 0.0059}
#
# ==================== Pennsylvania_trend [6/25] ====================
# {'units': 32, 'dropout': 0.0, 'learning_rate': 0.0206}
#
# ==================== Pennsylvania_region+trend [6/25] ====================
# {'units': 256, 'dropout': 0.2, 'learning_rate': 0.0108}
#
# ==================== Ohio_no_timedata [7/25] ====================
# {'units': 32, 'dropout': 0.0, 'learning_rate': 0.0402}
#
# ==================== Ohio_region [7/25] ====================
# {'units': 16, 'dropout': 0.2, 'learning_rate': 0.0059}
#
# ==================== Ohio_trend [7/25] ====================
# {'units': 32, 'dropout': 0.1, 'learning_rate': 0.0304}
#
# ==================== Ohio_region+trend [7/25] ====================
# {'units': 16, 'dropout': 0.2, 'learning_rate': 0.0157}
#
# ==================== North Carolina_no_timedata [8/25] ====================
# {'units': 16, 'dropout': 0.0, 'learning_rate': 0.0353}
#
# ==================== North Carolina_region [8/25] ====================
# {'units': 16, 'dropout': 0.3, 'learning_rate': 0.025500000000000002}
#
# ==================== North Carolina_trend [8/25] ====================
# {'units': 32, 'dropout': 0.1, 'learning_rate': 0.0059}
#
# ==================== North Carolina_region+trend [8/25] ====================
# {'units': 128, 'dropout': 0.3, 'learning_rate': 0.0157}
#
# ==================== Georgia_no_timedata [9/25] ====================
# {'units': 64, 'dropout': 0.0, 'learning_rate': 0.0059}
#
# ==================== Georgia_region [9/25] ====================
# {'units': 128, 'dropout': 0.2, 'learning_rate': 0.0059}
#
# ==================== Georgia_trend [9/25] ====================
# {'units': 64, 'dropout': 0.1, 'learning_rate': 0.0304}
#
# ==================== Georgia_region+trend [9/25] ====================
# {'units': 16, 'dropout': 0.3, 'learning_rate': 0.0206}
#
# ==================== New Jersey_no_timedata [10/25] ====================
# {'units': 128, 'dropout': 0.1, 'learning_rate': 0.0108}
#
# ==================== New Jersey_region [10/25] ====================
# {'units': 128, 'dropout': 0.1, 'learning_rate': 0.001}
#
# ==================== New Jersey_trend [10/25] ====================
# {'units': 256, 'dropout': 0.1, 'learning_rate': 0.001}
#
# ==================== New Jersey_region+trend [10/25] ====================
# {'units': 64, 'dropout': 0.3, 'learning_rate': 0.0206}
#
# ==================== Arizona_no_timedata [11/25] ====================
# {'units': 32, 'dropout': 0.0, 'learning_rate': 0.0206}
#
# ==================== Arizona_region [11/25] ====================
# {'units': 256, 'dropout': 0.0, 'learning_rate': 0.0108}
#
# ==================== Arizona_trend [11/25] ====================
# {'units': 128, 'dropout': 0.2, 'learning_rate': 0.0059}
#
# ==================== Arizona_region+trend [11/25] ====================
# {'units': 128, 'dropout': 0.0, 'learning_rate': 0.0108}
#
# ==================== Michigan_no_timedata [12/25] ====================
# {'units': 128, 'dropout': 0.1, 'learning_rate': 0.0402}
#
# ==================== Michigan_region [12/25] ====================
# {'units': 64, 'dropout': 0.1, 'learning_rate': 0.0108}
#
# ==================== Michigan_trend [12/25] ====================
# {'units': 64, 'dropout': 0.0, 'learning_rate': 0.0353}
#
# ==================== Michigan_region+trend [12/25] ====================
# {'units': 16, 'dropout': 0.1, 'learning_rate': 0.0059}
#
# ==================== Tennessee_no_timedata [13/25] ====================
# {'units': 16, 'dropout': 0.0, 'learning_rate': 0.025500000000000002}
#
# ==================== Tennessee_region [13/25] ====================
# {'units': 16, 'dropout': 0.0, 'learning_rate': 0.0108}
#
# ==================== Tennessee_trend [13/25] ====================
# {'units': 32, 'dropout': 0.0, 'learning_rate': 0.0451}
#
# ==================== Tennessee_region+trend [13/25] ====================
# {'units': 16, 'dropout': 0.0, 'learning_rate': 0.0157}
#
# ==================== Indiana_no_timedata [14/25] ====================
# {'units': 128, 'dropout': 0.0, 'learning_rate': 0.0059}
#
# ==================== Indiana_region [14/25] ====================
# {'units': 64, 'dropout': 0.0, 'learning_rate': 0.0108}
#
# ==================== Indiana_trend [14/25] ====================
# {'units': 128, 'dropout': 0.0, 'learning_rate': 0.0059}
#
# ==================== Indiana_region+trend [14/25] ====================
# {'units': 32, 'dropout': 0.3, 'learning_rate': 0.0108}
#
# ==================== Virginia_no_timedata [15/25] ====================
# {'units': 32, 'dropout': 0.2, 'learning_rate': 0.0108}
#
# ==================== Virginia_region [15/25] ====================
# {'units': 32, 'dropout': 0.1, 'learning_rate': 0.0157}
#
# ==================== Virginia_trend [15/25] ====================
# {'units': 16, 'dropout': 0.3, 'learning_rate': 0.0304}
#
# ==================== Virginia_region+trend [15/25] ====================
# {'units': 16, 'dropout': 0.3, 'learning_rate': 0.0402}
#
# ==================== Minnesota_no_timedata [16/25] ====================
# {'units': 16, 'dropout': 0.1, 'learning_rate': 0.0059}
#
# ==================== Minnesota_region [16/25] ====================
# {'units': 64, 'dropout': 0.0, 'learning_rate': 0.0059}
#
# ==================== Minnesota_trend [16/25] ====================
# {'units': 32, 'dropout': 0.2, 'learning_rate': 0.0059}
#
# ==================== Minnesota_region+trend [16/25] ====================
# {'units': 64, 'dropout': 0.0, 'learning_rate': 0.0059}
#
# ==================== South Carolina_no_timedata [17/25] ====================
# {'units': 16, 'dropout': 0.1, 'learning_rate': 0.0108}
#
# ==================== South Carolina_region [17/25] ====================
# {'units': 16, 'dropout': 0.1, 'learning_rate': 0.0402}
#
# ==================== South Carolina_trend [17/25] ====================
# {'units': 16, 'dropout': 0.0, 'learning_rate': 0.0402}
#
# ==================== South Carolina_region+trend [17/25] ====================
# {'units': 32, 'dropout': 0.2, 'learning_rate': 0.025500000000000002}
#
# ==================== Massachusetts_no_timedata [18/25] ====================
# {'units': 32, 'dropout': 0.3, 'learning_rate': 0.0206}
#
# ==================== Massachusetts_region [18/25] ====================
# {'units': 32, 'dropout': 0.0, 'learning_rate': 0.0108}
#
# ==================== Massachusetts_trend [18/25] ====================
# {'units': 64, 'dropout': 0.1, 'learning_rate': 0.0353}
#
# ==================== Massachusetts_region+trend [18/25] ====================
# {'units': 16, 'dropout': 0.2, 'learning_rate': 0.0206}
#
# ==================== Louisiana_no_timedata [19/25] ====================
# {'units': 16, 'dropout': 0.0, 'learning_rate': 0.0402}
#
# ==================== Louisiana_region [19/25] ====================
# {'units': 16, 'dropout': 0.0, 'learning_rate': 0.0206}
#
# ==================== Louisiana_trend [19/25] ====================
# {'units': 32, 'dropout': 0.0, 'learning_rate': 0.05}
#
# ==================== Louisiana_region+trend [19/25] ====================
# {'units': 16, 'dropout': 0.0, 'learning_rate': 0.025500000000000002}
#
# ==================== Wisconsin_no_timedata [20/25] ====================
# {'units': 128, 'dropout': 0.0, 'learning_rate': 0.0059}
#
# ==================== Wisconsin_region [20/25] ====================
# {'units': 64, 'dropout': 0.1, 'learning_rate': 0.0157}
#
# ==================== Wisconsin_trend [20/25] ====================
# {'units': 128, 'dropout': 0.2, 'learning_rate': 0.0059}
#
# ==================== Wisconsin_region+trend [20/25] ====================
# {'units': 64, 'dropout': 0.0, 'learning_rate': 0.0108}
#
# ==================== Maryland_no_timedata [21/25] ====================
# {'units': 128, 'dropout': 0.2, 'learning_rate': 0.001}
#
# ==================== Maryland_region [21/25] ====================
# {'units': 64, 'dropout': 0.2, 'learning_rate': 0.0157}
#
# ==================== Maryland_trend [21/25] ====================
# {'units': 128, 'dropout': 0.1, 'learning_rate': 0.0157}
#
# ==================== Maryland_region+trend [21/25] ====================
# {'units': 16, 'dropout': 0.1, 'learning_rate': 0.0402}
#
# ==================== Oklahoma_no_timedata [22/25] ====================
# {'units': 128, 'dropout': 0.1, 'learning_rate': 0.0059}
#
# ==================== Oklahoma_region [22/25] ====================
# {'units': 128, 'dropout': 0.0, 'learning_rate': 0.0059}
#
# ==================== Oklahoma_trend [22/25] ====================
# {'units': 32, 'dropout': 0.1, 'learning_rate': 0.0059}
#
# ==================== Oklahoma_region+trend [22/25] ====================
# {'units': 256, 'dropout': 0.1, 'learning_rate': 0.0108}
#
# ==================== Alabama_no_timedata [23/25] ====================
# {'units': 16, 'dropout': 0.1, 'learning_rate': 0.025500000000000002}
#
# ==================== Alabama_region [23/25] ====================
# {'units': 64, 'dropout': 0.1, 'learning_rate': 0.0157}
#
# ==================== Alabama_trend [23/25] ====================
# {'units': 64, 'dropout': 0.0, 'learning_rate': 0.0108}
#
# ==================== Alabama_region+trend [23/25] ====================
# {'units': 32, 'dropout': 0.0, 'learning_rate': 0.0157}
#
# ==================== Missouri_no_timedata [24/25] ====================
# {'units': 64, 'dropout': 0.0, 'learning_rate': 0.0059}
#
# ==================== Missouri_region [24/25] ====================
# {'units': 64, 'dropout': 0.2, 'learning_rate': 0.0108}
#
# ==================== Missouri_trend [24/25] ====================
# {'units': 16, 'dropout': 0.1, 'learning_rate': 0.0206}
#
# ==================== Missouri_region+trend [24/25] ====================
# {'units': 16, 'dropout': 0.1, 'learning_rate': 0.0108}
#
# ==================== Colorado_no_timedata [25/25] ====================
# {'units': 32, 'dropout': 0.1, 'learning_rate': 0.0059}
#
# ==================== Colorado_region [25/25] ====================
# {'units': 64, 'dropout': 0.0, 'learning_rate': 0.0304}
#
# ==================== Colorado_trend [25/25] ====================
# {'units': 32, 'dropout': 0.3, 'learning_rate': 0.0206}
#
# ==================== Colorado_region+trend [25/25] ====================
# {'units': 64, 'dropout': 0.3, 'learning_rate': 0.001}

# %% [markdown]
# ## TCN 튜닝

# %%
model_name = 'tcn'

for state in target_states:
    if not state in list(hparams.keys()): hparams[state] = {}
    #현제 진행하고 있는 주 이름, 진행상황 표시
    progress = '[' + str(list(hparams.keys()).index(state) + 1) + '/' + str(len(target_states)) + ']'
    print('='*20, state + "_" + progress, '='*20)
    
    #저장할 파일 이름 정의
    save_name = state + "_" + model_name
    
    #주 데이터 구하기
    states_data = scaled_epidemic[scaled_epidemic['key'] == get_region_code(state)]['new_confirmed'].to_numpy()

    #데이터 생성
    train, valid, test = DataSplit(
        states_data, 
        states_data, 
        look_back, 
        look_ahead, 
        split_rate=dataset_split, 
        time_data=None,
        teacher_force=False, 
    )
        
    #케라스 튜너
    tuner = kt.Hyperband(
        model_tcn(1), 
        objective = 'val_loss', 
        max_epochs=max_epochs,
        directory="./turning",
        project_name = save_name
    )
        
    #하이퍼 파라메터 검색
    tuner.search(
        train[0],
        train[1], 
        validation_data=(valid[0], valid[1]),
        batch_size=batch_size,
        epochs=epochs,
        shuffle = False, 
        verbose = 0, 
        workers = 4,
    )
        
    #최적 파라메터 저장
    best_hps = tuner.get_best_hyperparameters()[0]
    hparams[state][model_name] = {
        'nb_filters' : best_hps.get('nb_filters'),
        'kernel_size' : best_hps.get('kernel_size'),
        'dropout' : best_hps.get('dropout'),
        'learning_rate' : best_hps.get('learning_rate')
    }
        
    #저장
    with open("./turning/hparams.pkl","wb") as fw:
        pickle.dump(hparams, fw)
    #end with
            
    #클리어 세션
    tf.keras.backend.clear_session() 
    print(hparams[state][model_name])
    print()
#end for
# Out:
# ==================== California_[1/25] ====================
# C:\Users\admin\anaconda3\envs\tf_env\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# {'nb_filters': 32, 'kernel_size': 8, 'dropout': 0.1, 'learning_rate': 0.007925000000000001}
#
# ==================== Florida_[2/25] ====================
# {'nb_filters': 16, 'kernel_size': 32, 'dropout': 0.2, 'learning_rate': 0.017825}
#
# ==================== New York_[3/25] ====================
# {'nb_filters': 32, 'kernel_size': 16, 'dropout': 0.1, 'learning_rate': 0.007925000000000001}
#
# ==================== Texas_[4/25] ====================
# {'nb_filters': 4, 'kernel_size': 32, 'dropout': 0.1, 'learning_rate': 0.0005}
#
# ==================== Illinois_[5/25] ====================
# {'nb_filters': 4, 'kernel_size': 32, 'dropout': 0.0, 'learning_rate': 0.002975}
#
# ==================== Pennsylvania_[6/25] ====================
# {'nb_filters': 16, 'kernel_size': 32, 'dropout': 0.3, 'learning_rate': 0.0005}
#
# ==================== Ohio_[7/25] ====================
# {'nb_filters': 16, 'kernel_size': 8, 'dropout': 0.3, 'learning_rate': 0.0005}
#
# ==================== North Carolina_[8/25] ====================
# {'nb_filters': 8, 'kernel_size': 16, 'dropout': 0.0, 'learning_rate': 0.00545}
#
# ==================== Georgia_[9/25] ====================
# {'nb_filters': 8, 'kernel_size': 4, 'dropout': 0.0, 'learning_rate': 0.010400000000000001}
#
# ==================== New Jersey_[10/25] ====================
# {'nb_filters': 32, 'kernel_size': 4, 'dropout': 0.1, 'learning_rate': 0.002975}
#
# ==================== Arizona_[11/25] ====================
# {'nb_filters': 16, 'kernel_size': 8, 'dropout': 0.1, 'learning_rate': 0.002975}
#
# ==================== Michigan_[12/25] ====================
# {'nb_filters': 4, 'kernel_size': 16, 'dropout': 0.1, 'learning_rate': 0.002975}
#
# ==================== Tennessee_[13/25] ====================
# {'nb_filters': 16, 'kernel_size': 16, 'dropout': 0.2, 'learning_rate': 0.002975}
#
# ==================== Indiana_[14/25] ====================
# {'nb_filters': 4, 'kernel_size': 8, 'dropout': 0.2, 'learning_rate': 0.002975}
#
# ==================== Virginia_[15/25] ====================
# {'nb_filters': 16, 'kernel_size': 4, 'dropout': 0.2, 'learning_rate': 0.012875000000000001}
#
# ==================== Minnesota_[16/25] ====================
# {'nb_filters': 8, 'kernel_size': 32, 'dropout': 0.1, 'learning_rate': 0.0005}
#
# ==================== South Carolina_[17/25] ====================
# {'nb_filters': 4, 'kernel_size': 32, 'dropout': 0.1, 'learning_rate': 0.002975}
#
# ==================== Massachusetts_[18/25] ====================
# {'nb_filters': 4, 'kernel_size': 32, 'dropout': 0.3, 'learning_rate': 0.0005}
#
# ==================== Louisiana_[19/25] ====================
# {'nb_filters': 32, 'kernel_size': 8, 'dropout': 0.2, 'learning_rate': 0.007925000000000001}
#
# ==================== Wisconsin_[20/25] ====================
# {'nb_filters': 32, 'kernel_size': 32, 'dropout': 0.3, 'learning_rate': 0.002975}
#
# ==================== Maryland_[21/25] ====================
# {'nb_filters': 4, 'kernel_size': 4, 'dropout': 0.0, 'learning_rate': 0.00545}
#
# ==================== Oklahoma_[22/25] ====================
# {'nb_filters': 16, 'kernel_size': 4, 'dropout': 0.1, 'learning_rate': 0.007925000000000001}
#
# ==================== Alabama_[23/25] ====================
# {'nb_filters': 8, 'kernel_size': 4, 'dropout': 0.0, 'learning_rate': 0.007925000000000001}
#
# ==================== Missouri_[24/25] ====================
# {'nb_filters': 32, 'kernel_size': 8, 'dropout': 0.1, 'learning_rate': 0.00545}
#
# ==================== Colorado_[25/25] ====================
# {'nb_filters': 4, 'kernel_size': 4, 'dropout': 0.2, 'learning_rate': 0.002975}

# %%
with open("./turning/hparams.pkl","wb") as fw:
    pickle.dump(hparams, fw)
#end with

# %%
hparams
# Out:
# {'California': {'lstm_no_timedata': {'units': 16,
#    'dropout': 0.1,
#    'learning_rate': 0.0353},
#   'lstm_region': {'units': 128, 'dropout': 0.3, 'learning_rate': 0.0304},
#   'lstm_trend': {'units': 64, 'dropout': 0.3, 'learning_rate': 0.0304},
#   'lstm_region+trend': {'units': 32, 'dropout': 0.1, 'learning_rate': 0.0304},
#   'seq2seq_no_timedata': {'units': 128,
#    'dropout': 0.0,
#    'learning_rate': 0.0059},
#   'seq2seq_region': {'units': 16, 'dropout': 0.1, 'learning_rate': 0.0451},
#   'seq2seq_trend': {'units': 16, 'dropout': 0.1, 'learning_rate': 0.0304},
#   'seq2seq_region+trend': {'units': 32,
#    'dropout': 0.0,
#    'learning_rate': 0.0157},
#   'tcn': {'nb_filters': 32,
#    'kernel_size': 8,
#    'dropout': 0.1,
#    'learning_rate': 0.007925000000000001}},
#  'Florida': {'lstm_no_timedata': {'units': 16,
#    'dropout': 0.0,
#    'learning_rate': 0.0402},
#   'lstm_region': {'units': 128, 'dropout': 0.0, 'learning_rate': 0.0206},
#   'lstm_trend': {'units': 128,
#    'dropout': 0.1,
#    'learning_rate': 0.025500000000000002},
#   'lstm_region+trend': {'units': 256, 'dropout': 0.0, 'learning_rate': 0.001},
#   'seq2seq_no_timedata': {'units': 16,
#    'dropout': 0.0,
#    'learning_rate': 0.025500000000000002},
#   'seq2seq_region': {'units': 64, 'dropout': 0.0, 'learning_rate': 0.0353},
#   'seq2seq_trend': {'units': 128, 'dropout': 0.0, 'learning_rate': 0.0108},
#   'seq2seq_region+trend': {'units': 32,
#    'dropout': 0.0,
#    'learning_rate': 0.0157},
#   'tcn': {'nb_filters': 16,
#    'kernel_size': 32,
#    'dropout': 0.2,
#    'learning_rate': 0.017825}},
#  'New York': {'lstm_no_timedata': {'units': 128,
#    'dropout': 0.1,
#    'learning_rate': 0.001},
#   'lstm_region': {'units': 16, 'dropout': 0.0, 'learning_rate': 0.0304},
#   'lstm_trend': {'units': 128, 'dropout': 0.1, 'learning_rate': 0.001},
#   'lstm_region+trend': {'units': 64, 'dropout': 0.1, 'learning_rate': 0.001},
#   'seq2seq_no_timedata': {'units': 32,
#    'dropout': 0.0,
#    'learning_rate': 0.0304},
#   'seq2seq_region': {'units': 32, 'dropout': 0.3, 'learning_rate': 0.0157},
#   'seq2seq_trend': {'units': 128, 'dropout': 0.3, 'learning_rate': 0.0157},
#   'seq2seq_region+trend': {'units': 16,
#    'dropout': 0.0,
#    'learning_rate': 0.0059},
#   'tcn': {'nb_filters': 32,
#    'kernel_size': 16,
#    'dropout': 0.1,
#    'learning_rate': 0.007925000000000001}},
#  'Texas': {'lstm_no_timedata': {'units': 32,
#    'dropout': 0.0,
#    'learning_rate': 0.001},
#   'lstm_region': {'units': 128, 'dropout': 0.3, 'learning_rate': 0.0304},
#   'lstm_trend': {'units': 64, 'dropout': 0.2, 'learning_rate': 0.0402},
#   'lstm_region+trend': {'units': 256,
#    'dropout': 0.0,
#    'learning_rate': 0.025500000000000002},
#   'seq2seq_no_timedata': {'units': 32,
#    'dropout': 0.0,
#    'learning_rate': 0.0304},
#   'seq2seq_region': {'units': 16, 'dropout': 0.0, 'learning_rate': 0.0108},
#   'seq2seq_trend': {'units': 16, 'dropout': 0.0, 'learning_rate': 0.0304},
#   'seq2seq_region+trend': {'units': 16,
#    'dropout': 0.3,
#    'learning_rate': 0.0353},
#   'tcn': {'nb_filters': 4,
#    'kernel_size': 32,
#    'dropout': 0.1,
#    'learning_rate': 0.0005}},
#  'Illinois': {'lstm_no_timedata': {'units': 128,
#    'dropout': 0.0,
#    'learning_rate': 0.0059},
#   'lstm_region': {'units': 64, 'dropout': 0.2, 'learning_rate': 0.0108},
#   'lstm_trend': {'units': 128, 'dropout': 0.1, 'learning_rate': 0.001},
#   'lstm_region+trend': {'units': 64, 'dropout': 0.2, 'learning_rate': 0.0157},
#   'seq2seq_no_timedata': {'units': 64,
#    'dropout': 0.1,
#    'learning_rate': 0.0206},
#   'seq2seq_region': {'units': 16, 'dropout': 0.1, 'learning_rate': 0.0059},
#   'seq2seq_trend': {'units': 128, 'dropout': 0.0, 'learning_rate': 0.0108},
#   'seq2seq_region+trend': {'units': 16,
#    'dropout': 0.3,
#    'learning_rate': 0.0304},
#   'tcn': {'nb_filters': 4,
#    'kernel_size': 32,
#    'dropout': 0.0,
#    'learning_rate': 0.002975}},
#  'Pennsylvania': {'lstm_no_timedata': {'units': 128,
#    'dropout': 0.2,
#    'learning_rate': 0.001},
#   'lstm_region': {'units': 16, 'dropout': 0.2, 'learning_rate': 0.0108},
#   'lstm_trend': {'units': 128, 'dropout': 0.2, 'learning_rate': 0.0108},
#   'lstm_region+trend': {'units': 128, 'dropout': 0.0, 'learning_rate': 0.0157},
#   'seq2seq_no_timedata': {'units': 32,
#    'dropout': 0.0,
#    'learning_rate': 0.025500000000000002},
#   'seq2seq_region': {'units': 16, 'dropout': 0.2, 'learning_rate': 0.0059},
#   'seq2seq_trend': {'units': 32, 'dropout': 0.0, 'learning_rate': 0.0206},
#   'seq2seq_region+trend': {'units': 256,
#    'dropout': 0.2,
#    'learning_rate': 0.0108},
#   'tcn': {'nb_filters': 16,
#    'kernel_size': 32,
#    'dropout': 0.3,
#    'learning_rate': 0.0005}},
#  'Ohio': {'lstm_no_timedata': {'units': 16,
#    'dropout': 0.1,
#    'learning_rate': 0.001},
#   'lstm_region': {'units': 16, 'dropout': 0.3, 'learning_rate': 0.0059},
#   'lstm_trend': {'units': 128, 'dropout': 0.0, 'learning_rate': 0.0108},
#   'lstm_region+trend': {'units': 64, 'dropout': 0.3, 'learning_rate': 0.0206},
#   'seq2seq_no_timedata': {'units': 32,
#    'dropout': 0.0,
#    'learning_rate': 0.0402},
#   'seq2seq_region': {'units': 16, 'dropout': 0.2, 'learning_rate': 0.0059},
#   'seq2seq_trend': {'units': 32, 'dropout': 0.1, 'learning_rate': 0.0304},
#   'seq2seq_region+trend': {'units': 16,
#    'dropout': 0.2,
#    'learning_rate': 0.0157},
#   'tcn': {'nb_filters': 16,
#    'kernel_size': 8,
#    'dropout': 0.3,
#    'learning_rate': 0.0005}},
#  'North Carolina': {'lstm_no_timedata': {'units': 32,
#    'dropout': 0.0,
#    'learning_rate': 0.0059},
#   'lstm_region': {'units': 16,
#    'dropout': 0.3,
#    'learning_rate': 0.025500000000000002},
#   'lstm_trend': {'units': 256, 'dropout': 0.0, 'learning_rate': 0.0206},
#   'lstm_region+trend': {'units': 256, 'dropout': 0.2, 'learning_rate': 0.0206},
#   'seq2seq_no_timedata': {'units': 16,
#    'dropout': 0.0,
#    'learning_rate': 0.0353},
#   'seq2seq_region': {'units': 16,
#    'dropout': 0.3,
#    'learning_rate': 0.025500000000000002},
#   'seq2seq_trend': {'units': 32, 'dropout': 0.1, 'learning_rate': 0.0059},
#   'seq2seq_region+trend': {'units': 128,
#    'dropout': 0.3,
#    'learning_rate': 0.0157},
#   'tcn': {'nb_filters': 8,
#    'kernel_size': 16,
#    'dropout': 0.0,
#    'learning_rate': 0.00545}},
#  'Georgia': {'lstm_no_timedata': {'units': 32,
#    'dropout': 0.1,
#    'learning_rate': 0.0451},
#   'lstm_region': {'units': 16, 'dropout': 0.3, 'learning_rate': 0.0402},
#   'lstm_trend': {'units': 32, 'dropout': 0.1, 'learning_rate': 0.0353},
#   'lstm_region+trend': {'units': 64,
#    'dropout': 0.3,
#    'learning_rate': 0.025500000000000002},
#   'seq2seq_no_timedata': {'units': 64,
#    'dropout': 0.0,
#    'learning_rate': 0.0059},
#   'seq2seq_region': {'units': 128, 'dropout': 0.2, 'learning_rate': 0.0059},
#   'seq2seq_trend': {'units': 64, 'dropout': 0.1, 'learning_rate': 0.0304},
#   'seq2seq_region+trend': {'units': 16,
#    'dropout': 0.3,
#    'learning_rate': 0.0206},
#   'tcn': {'nb_filters': 8,
#    'kernel_size': 4,
#    'dropout': 0.0,
#    'learning_rate': 0.010400000000000001}},
#  'New Jersey': {'lstm_no_timedata': {'units': 32,
#    'dropout': 0.1,
#    'learning_rate': 0.001},
#   'lstm_region': {'units': 32,
#    'dropout': 0.3,
#    'learning_rate': 0.025500000000000002},
#   'lstm_trend': {'units': 32, 'dropout': 0.1, 'learning_rate': 0.0108},
#   'lstm_region+trend': {'units': 16, 'dropout': 0.1, 'learning_rate': 0.0206},
#   'seq2seq_no_timedata': {'units': 128,
#    'dropout': 0.1,
#    'learning_rate': 0.0108},
#   'seq2seq_region': {'units': 128, 'dropout': 0.1, 'learning_rate': 0.001},
#   'seq2seq_trend': {'units': 256, 'dropout': 0.1, 'learning_rate': 0.001},
#   'seq2seq_region+trend': {'units': 64,
#    'dropout': 0.3,
#    'learning_rate': 0.0206},
#   'tcn': {'nb_filters': 32,
#    'kernel_size': 4,
#    'dropout': 0.1,
#    'learning_rate': 0.002975}},
#  'Arizona': {'lstm_no_timedata': {'units': 64,
#    'dropout': 0.2,
#    'learning_rate': 0.025500000000000002},
#   'lstm_region': {'units': 128, 'dropout': 0.3, 'learning_rate': 0.0353},
#   'lstm_trend': {'units': 32, 'dropout': 0.1, 'learning_rate': 0.0304},
#   'lstm_region+trend': {'units': 64, 'dropout': 0.3, 'learning_rate': 0.0206},
#   'seq2seq_no_timedata': {'units': 32,
#    'dropout': 0.0,
#    'learning_rate': 0.0206},
#   'seq2seq_region': {'units': 256, 'dropout': 0.0, 'learning_rate': 0.0108},
#   'seq2seq_trend': {'units': 128, 'dropout': 0.2, 'learning_rate': 0.0059},
#   'seq2seq_region+trend': {'units': 128,
#    'dropout': 0.0,
#    'learning_rate': 0.0108},
#   'tcn': {'nb_filters': 16,
#    'kernel_size': 8,
#    'dropout': 0.1,
#    'learning_rate': 0.002975}},
#  'Michigan': {'lstm_no_timedata': {'units': 128,
#    'dropout': 0.2,
#    'learning_rate': 0.0059},
#   'lstm_region': {'units': 16, 'dropout': 0.1, 'learning_rate': 0.0108},
#   'lstm_trend': {'units': 32, 'dropout': 0.0, 'learning_rate': 0.001},
#   'lstm_region+trend': {'units': 64,
#    'dropout': 0.2,
#    'learning_rate': 0.025500000000000002},
#   'seq2seq_no_timedata': {'units': 128,
#    'dropout': 0.1,
#    'learning_rate': 0.0402},
#   'seq2seq_region': {'units': 64, 'dropout': 0.1, 'learning_rate': 0.0108},
#   'seq2seq_trend': {'units': 64, 'dropout': 0.0, 'learning_rate': 0.0353},
#   'seq2seq_region+trend': {'units': 16,
#    'dropout': 0.1,
#    'learning_rate': 0.0059},
#   'tcn': {'nb_filters': 4,
#    'kernel_size': 16,
#    'dropout': 0.1,
#    'learning_rate': 0.002975}},
#  'Tennessee': {'lstm_no_timedata': {'units': 32,
#    'dropout': 0.1,
#    'learning_rate': 0.0157},
#   'lstm_region': {'units': 128, 'dropout': 0.3, 'learning_rate': 0.0157},
#   'lstm_trend': {'units': 16, 'dropout': 0.2, 'learning_rate': 0.0108},
#   'lstm_region+trend': {'units': 32, 'dropout': 0.3, 'learning_rate': 0.0157},
#   'seq2seq_no_timedata': {'units': 16,
#    'dropout': 0.0,
#    'learning_rate': 0.025500000000000002},
#   'seq2seq_region': {'units': 16, 'dropout': 0.0, 'learning_rate': 0.0108},
#   'seq2seq_trend': {'units': 32, 'dropout': 0.0, 'learning_rate': 0.0451},
#   'seq2seq_region+trend': {'units': 16,
#    'dropout': 0.0,
#    'learning_rate': 0.0157},
#   'tcn': {'nb_filters': 16,
#    'kernel_size': 16,
#    'dropout': 0.2,
#    'learning_rate': 0.002975}},
#  'Indiana': {'lstm_no_timedata': {'units': 128,
#    'dropout': 0.3,
#    'learning_rate': 0.001},
#   'lstm_region': {'units': 128, 'dropout': 0.1, 'learning_rate': 0.0059},
#   'lstm_trend': {'units': 32,
#    'dropout': 0.0,
#    'learning_rate': 0.025500000000000002},
#   'lstm_region+trend': {'units': 256, 'dropout': 0.2, 'learning_rate': 0.001},
#   'seq2seq_no_timedata': {'units': 128,
#    'dropout': 0.0,
#    'learning_rate': 0.0059},
#   'seq2seq_region': {'units': 64, 'dropout': 0.0, 'learning_rate': 0.0108},
#   'seq2seq_trend': {'units': 128, 'dropout': 0.0, 'learning_rate': 0.0059},
#   'seq2seq_region+trend': {'units': 32,
#    'dropout': 0.3,
#    'learning_rate': 0.0108},
#   'tcn': {'nb_filters': 4,
#    'kernel_size': 8,
#    'dropout': 0.2,
#    'learning_rate': 0.002975}},
#  'Virginia': {'lstm_no_timedata': {'units': 64,
#    'dropout': 0.1,
#    'learning_rate': 0.0353},
#   'lstm_region': {'units': 64, 'dropout': 0.2, 'learning_rate': 0.0304},
#   'lstm_trend': {'units': 256, 'dropout': 0.0, 'learning_rate': 0.0108},
#   'lstm_region+trend': {'units': 16, 'dropout': 0.1, 'learning_rate': 0.0206},
#   'seq2seq_no_timedata': {'units': 32,
#    'dropout': 0.2,
#    'learning_rate': 0.0108},
#   'seq2seq_region': {'units': 32, 'dropout': 0.1, 'learning_rate': 0.0157},
#   'seq2seq_trend': {'units': 16, 'dropout': 0.3, 'learning_rate': 0.0304},
#   'seq2seq_region+trend': {'units': 16,
#    'dropout': 0.3,
#    'learning_rate': 0.0402},
#   'tcn': {'nb_filters': 16,
#    'kernel_size': 4,
#    'dropout': 0.2,
#    'learning_rate': 0.012875000000000001}},
#  'Minnesota': {'lstm_no_timedata': {'units': 256,
#    'dropout': 0.0,
#    'learning_rate': 0.001},
#   'lstm_region': {'units': 64, 'dropout': 0.2, 'learning_rate': 0.001},
#   'lstm_trend': {'units': 64,
#    'dropout': 0.2,
#    'learning_rate': 0.025500000000000002},
#   'lstm_region+trend': {'units': 128, 'dropout': 0.1, 'learning_rate': 0.0157},
#   'seq2seq_no_timedata': {'units': 16,
#    'dropout': 0.1,
#    'learning_rate': 0.0059},
#   'seq2seq_region': {'units': 64, 'dropout': 0.0, 'learning_rate': 0.0059},
#   'seq2seq_trend': {'units': 32, 'dropout': 0.2, 'learning_rate': 0.0059},
#   'seq2seq_region+trend': {'units': 64,
#    'dropout': 0.0,
#    'learning_rate': 0.0059},
#   'tcn': {'nb_filters': 8,
#    'kernel_size': 32,
#    'dropout': 0.1,
#    'learning_rate': 0.0005}},
#  'South Carolina': {'lstm_no_timedata': {'units': 128,
#    'dropout': 0.2,
#    'learning_rate': 0.0059},
#   'lstm_region': {'units': 128, 'dropout': 0.3, 'learning_rate': 0.0304},
#   'lstm_trend': {'units': 16, 'dropout': 0.0, 'learning_rate': 0.0353},
#   'lstm_region+trend': {'units': 64, 'dropout': 0.3, 'learning_rate': 0.0157},
#   'seq2seq_no_timedata': {'units': 16,
#    'dropout': 0.1,
#    'learning_rate': 0.0108},
#   'seq2seq_region': {'units': 16, 'dropout': 0.1, 'learning_rate': 0.0402},
#   'seq2seq_trend': {'units': 16, 'dropout': 0.0, 'learning_rate': 0.0402},
#   'seq2seq_region+trend': {'units': 32,
#    'dropout': 0.2,
#    'learning_rate': 0.025500000000000002},
#   'tcn': {'nb_filters': 4,
#    'kernel_size': 32,
#    'dropout': 0.1,
#    'learning_rate': 0.002975}},
#  'Massachusetts': {'lstm_no_timedata': {'units': 16,
#    'dropout': 0.1,
#    'learning_rate': 0.001},
#   'lstm_region': {'units': 64, 'dropout': 0.0, 'learning_rate': 0.0059},
#   'lstm_trend': {'units': 32, 'dropout': 0.2, 'learning_rate': 0.0059},
#   'lstm_region+trend': {'units': 256, 'dropout': 0.3, 'learning_rate': 0.0108},
#   'seq2seq_no_timedata': {'units': 32,
#    'dropout': 0.3,
#    'learning_rate': 0.0206},
#   'seq2seq_region': {'units': 32, 'dropout': 0.0, 'learning_rate': 0.0108},
#   'seq2seq_trend': {'units': 64, 'dropout': 0.1, 'learning_rate': 0.0353},
#   'seq2seq_region+trend': {'units': 16,
#    'dropout': 0.2,
#    'learning_rate': 0.0206},
#   'tcn': {'nb_filters': 4,
#    'kernel_size': 32,
#    'dropout': 0.3,
#    'learning_rate': 0.0005}},
#  'Louisiana': {'lstm_no_timedata': {'units': 32,
#    'dropout': 0.1,
#    'learning_rate': 0.0304},
#   'lstm_region': {'units': 256, 'dropout': 0.2, 'learning_rate': 0.0304},
#   'lstm_trend': {'units': 32, 'dropout': 0.0, 'learning_rate': 0.0353},
#   'lstm_region+trend': {'units': 128, 'dropout': 0.0, 'learning_rate': 0.001},
#   'seq2seq_no_timedata': {'units': 16,
#    'dropout': 0.0,
#    'learning_rate': 0.0402},
#   'seq2seq_region': {'units': 16, 'dropout': 0.0, 'learning_rate': 0.0206},
#   'seq2seq_trend': {'units': 32, 'dropout': 0.0, 'learning_rate': 0.05},
#   'seq2seq_region+trend': {'units': 16,
#    'dropout': 0.0,
#    'learning_rate': 0.025500000000000002},
#   'tcn': {'nb_filters': 32,
#    'kernel_size': 8,
#    'dropout': 0.2,
#    'learning_rate': 0.007925000000000001}},
#  'Wisconsin': {'lstm_no_timedata': {'units': 16,
#    'dropout': 0.3,
#    'learning_rate': 0.001},
#   'lstm_region': {'units': 256, 'dropout': 0.2, 'learning_rate': 0.0059},
#   'lstm_trend': {'units': 64, 'dropout': 0.0, 'learning_rate': 0.0402},
#   'lstm_region+trend': {'units': 256, 'dropout': 0.1, 'learning_rate': 0.0206},
#   'seq2seq_no_timedata': {'units': 128,
#    'dropout': 0.0,
#    'learning_rate': 0.0059},
#   'seq2seq_region': {'units': 64, 'dropout': 0.1, 'learning_rate': 0.0157},
#   'seq2seq_trend': {'units': 128, 'dropout': 0.2, 'learning_rate': 0.0059},
#   'seq2seq_region+trend': {'units': 64,
#    'dropout': 0.0,
#    'learning_rate': 0.0108},
#   'tcn': {'nb_filters': 32,
#    'kernel_size': 32,
#    'dropout': 0.3,
#    'learning_rate': 0.002975}},
#  'Maryland': {'lstm_no_timedata': {'units': 128,
#    'dropout': 0.3,
#    'learning_rate': 0.0206},
#   'lstm_region': {'units': 256, 'dropout': 0.0, 'learning_rate': 0.001},
#   'lstm_trend': {'units': 128, 'dropout': 0.1, 'learning_rate': 0.0206},
#   'lstm_region+trend': {'units': 32, 'dropout': 0.0, 'learning_rate': 0.0304},
#   'seq2seq_no_timedata': {'units': 128,
#    'dropout': 0.2,
#    'learning_rate': 0.001},
#   'seq2seq_region': {'units': 64, 'dropout': 0.2, 'learning_rate': 0.0157},
#   'seq2seq_trend': {'units': 128, 'dropout': 0.1, 'learning_rate': 0.0157},
#   'seq2seq_region+trend': {'units': 16,
#    'dropout': 0.1,
#    'learning_rate': 0.0402},
#   'tcn': {'nb_filters': 4,
#    'kernel_size': 4,
#    'dropout': 0.0,
#    'learning_rate': 0.00545}},
#  'Oklahoma': {'lstm_no_timedata': {'units': 128,
#    'dropout': 0.2,
#    'learning_rate': 0.0059},
#   'lstm_region': {'units': 256, 'dropout': 0.0, 'learning_rate': 0.001},
#   'lstm_trend': {'units': 64, 'dropout': 0.1, 'learning_rate': 0.0157},
#   'lstm_region+trend': {'units': 256, 'dropout': 0.0, 'learning_rate': 0.0157},
#   'seq2seq_no_timedata': {'units': 128,
#    'dropout': 0.1,
#    'learning_rate': 0.0059},
#   'seq2seq_region': {'units': 128, 'dropout': 0.0, 'learning_rate': 0.0059},
#   'seq2seq_trend': {'units': 32, 'dropout': 0.1, 'learning_rate': 0.0059},
#   'seq2seq_region+trend': {'units': 256,
#    'dropout': 0.1,
#    'learning_rate': 0.0108},
#   'tcn': {'nb_filters': 16,
#    'kernel_size': 4,
#    'dropout': 0.1,
#    'learning_rate': 0.007925000000000001}},
#  'Alabama': {'lstm_no_timedata': {'units': 16,
#    'dropout': 0.2,
#    'learning_rate': 0.0353},
#   'lstm_region': {'units': 128, 'dropout': 0.0, 'learning_rate': 0.05},
#   'lstm_trend': {'units': 64, 'dropout': 0.2, 'learning_rate': 0.0304},
#   'lstm_region+trend': {'units': 32, 'dropout': 0.3, 'learning_rate': 0.0451},
#   'seq2seq_no_timedata': {'units': 16,
#    'dropout': 0.1,
#    'learning_rate': 0.025500000000000002},
#   'seq2seq_region': {'units': 64, 'dropout': 0.1, 'learning_rate': 0.0157},
#   'seq2seq_trend': {'units': 64, 'dropout': 0.0, 'learning_rate': 0.0108},
#   'seq2seq_region+trend': {'units': 32,
#    'dropout': 0.0,
#    'learning_rate': 0.0157},
#   'tcn': {'nb_filters': 8,
#    'kernel_size': 4,
#    'dropout': 0.0,
#    'learning_rate': 0.007925000000000001}},
#  'Missouri': {'lstm_no_timedata': {'units': 128,
#    'dropout': 0.1,
#    'learning_rate': 0.0157},
#   'lstm_region': {'units': 128, 'dropout': 0.2, 'learning_rate': 0.0157},
#   'lstm_trend': {'units': 256, 'dropout': 0.0, 'learning_rate': 0.0157},
#   'lstm_region+trend': {'units': 64, 'dropout': 0.0, 'learning_rate': 0.0451},
#   'seq2seq_no_timedata': {'units': 64,
#    'dropout': 0.0,
#    'learning_rate': 0.0059},
#   'seq2seq_region': {'units': 64, 'dropout': 0.2, 'learning_rate': 0.0108},
#   'seq2seq_trend': {'units': 16, 'dropout': 0.1, 'learning_rate': 0.0206},
#   'seq2seq_region+trend': {'units': 16,
#    'dropout': 0.1,
#    'learning_rate': 0.0108},
#   'tcn': {'nb_filters': 32,
#    'kernel_size': 8,
#    'dropout': 0.1,
#    'learning_rate': 0.00545}},
#  'Colorado': {'lstm_no_timedata': {'units': 256,
#    'dropout': 0.0,
#    'learning_rate': 0.001},
#   'lstm_region': {'units': 256, 'dropout': 0.3, 'learning_rate': 0.001},
#   'lstm_trend': {'units': 128, 'dropout': 0.3, 'learning_rate': 0.0108},
#   'lstm_region+trend': {'units': 16,
#    'dropout': 0.0,
#    'learning_rate': 0.025500000000000002},
#   'seq2seq_no_timedata': {'units': 32,
#    'dropout': 0.1,
#    'learning_rate': 0.0059},
#   'seq2seq_region': {'units': 64, 'dropout': 0.0, 'learning_rate': 0.0304},
#   'seq2seq_trend': {'units': 32, 'dropout': 0.3, 'learning_rate': 0.0206},
#   'seq2seq_region+trend': {'units': 64,
#    'dropout': 0.3,
#    'learning_rate': 0.001},
#   'tcn': {'nb_filters': 4,
#    'kernel_size': 4,
#    'dropout': 0.2,
#    'learning_rate': 0.002975}}}
